# %% [markdown]
# ## Ejercicios de Matplotlib

# %% [markdown]
# 1. Importa pyplot, numpy y pandas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# 2. Sabemos que podemos pintar gráficas de dos formas: la figura incluye los ejes o teniendo figura y ejes por separado.
#
# Usando solo una figura, usa numpy para los valores del eje X entre 0 y 5.
#
# Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5).
#
# Elige la precisión en el eje X que desees.

# %%
# Usando solo una figura, usa numpy para los valores del eje X entre 0 y 5. 
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 5, 100)
ax.plot(x);

# %%
# Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente 
# positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3
#  que pase por (0,-5). 

# Elige la precisión en el eje X que desees.  

fig, axs = plt.subplots(nrows=1, ncols=2, layout='constrained', figsize=(10, 4))
x = np.linspace(-10, 10, 100)

y1 = 3 * x                 # pendiente +3, pasa por (0, 0)
y2 = -3 * x - 5            # pendiente -3, pasa por (0, -5)

for nn, ax in enumerate(axs):
    ax.set_xlabel("eje X")
    ax.set_ylabel("eje Y")
    ax.axhline(0, color="red", linewidth=0.25)
    ax.axvline(0, color="red", linewidth=0.25)
    if nn == 1:
        ax.set_title('Automatic ticks/ Recta baja')
        plt.subplot(1, 2, 1);
        plt.plot(x, y2, label='y = 3x', color='blue');
    else:
        ax.set_title('Manual ticks/ Recta sube')
        plt.subplot(1, 2, 2);
        ax.set_xticks(np.arange(-10, 10, 10/10))
        plt.plot(x, y1, label='y = -3x - 5', color='red');

# %% [markdown]
# 3. Fija el eje X entre 0 y 5 y el eje Y entre -15 y 15

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(-10, 10, 100)
y = np.linspace(-20, 20, 100)

plt.plot(x, y, '-b')

# ax.set_xlim(0,5)
# ax.set_ylim(-15,15)

# con xlim, ylim
plt.xlim(0, 5)
plt.ylim(-15, 15)
# Out:
# (-15.0, 15.0)

# %%
# Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente 
# positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3
#  que pase por (0,-5). 

# Elige la precisión en el eje X que desees.  

fig, axs = plt.subplots(nrows=1, ncols=2, layout='constrained', figsize=(10, 4))
x = np.linspace(-10, 10, 100)

y1 = 3 * x                 # pendiente +3, pasa por (0, 0)
y2 = -3 * x - 5            # pendiente -3, pasa por (0, -5)

for nn, ax in enumerate(axs):
    ax.set_xlabel("eje X")                               # plt.xLabel()
    ax.axhline(0, color="red", linewidth=0.25)         
    ax.axvline(0, color="red", linewidth=0.25)
    
    if nn == 1:
        ax.set_title('Automatic ticks/ Recta baja')     # plt.title()
        plt.subplot(1, 2, 1);
        plt.plot(x, y2, label='y = 3x', color='blue');
        plt.xlim(0, 5)
        plt.ylim(-15, 15)
    else:
        ax.set_title('Manual ticks/ Recta sube')
        ax.set_ylabel("eje Y")
        plt.subplot(1, 2, 2);
        ax.set_xticks(np.arange(-10, 10, 5/10))
        plt.plot(x, y1, label='y = -3x - 5', color='red');
        plt.xlim(0, 5)
        plt.ylim(-15, 15)

# %% [markdown]
# 4. Llama al eje X "eje X", al eje Y "eje Y" y pon de títulos "recta sube" y "recta baja". Muestra dos etiquetas de ejeX pero solo una de eje Y.

# %% [markdown]
#         ver más arriba en la de dos gráficas

# %% [markdown]
# 5. Usando una figura Y EJES POR SEPARADO, usa numpy para los valores del eje X entre 0 y 5. Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5). Elige la precisión en el eje X que desees.

# %%
x = np.linspace(0, 5, 100)

fig = plt.figure(figsize=(10, 4))

ax1 = fig.add_axes([0.1, 0.2, 0.35, 0.6])
ax1.plot(x, 3 * x, 'b')  # y = 3x
ax1.set_xticks(np.arange(0, 5, 5/10))
ax1.set_title('Recta Positiva')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')

ax2 = fig.add_axes([0.55, 0.2, 0.35, 0.6])
ax2.plot(x, -3 * x - 5, 'r')  # y = -3x - 5
ax2.set_title('Recta Negativa')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')

plt.show()

# %% [markdown]
# 6. Crea una lista de coordenadas X: 20, 22, 24, 26, 28
# Crea una lista de coordenadas Y: 5, 15, -5, 20, 5
# Usa un gráfico de barras colocadas en X con alturas Y

# %%
x = [20, 22, 24, 26, 28]
y = [5, 15, -5, 20, 5]

fig = plt.figure()
ax = plt.axes()

# ax.axhline(0, color="black", linewidth=0.25)

plt.bar(x, y, color='skyblue')
plt.xlabel('eje X')
plt.ylabel('eje Y')
plt.title('Ejercicio 6')
plt.show()

# %% [markdown]
# 7. Crea un gráfico de barras. Pintamos la altura de un grupo de amigos, cada barra representa a una persona. Ana mide 160 cm, Luis mide 180 cm, Pedro mide 175 cm, Sofía mide 190 cm, Carmen mide 170 cm. Las barras serán verdes.
# Consejo: si no vas a tener que manipular especialmente los ejes, es más sencillo dejarlos dentro de la figura.

# %%
alturas = [1.6, 1.8, 1.75, 1.9, 1.7]
nombres = ['ana', 'luis', 'pedro', 'sofia', 'carmen']

fig = plt.figure()
ax = plt.axes()

bar_chart = plt.bar(nombres, alturas, color='#00a2a1')
ax.bar_label(bar_chart, label_type='center', color='white')

plt.xlabel('Nombres')
plt.ylabel('Alturas (m)')
plt.title('Ejercicio 7')
plt.show()

# %%
# TODO: Ordenar para que quede mas claro!

# %%
alturas = [1.6, 1.8, 1.75, 1.9, 1.7]
nombres = ['ana', 'luis', 'pedro', 'sofia', 'carmen']

df = pd.DataFrame({"Alturas": alturas}, index=nombres).sort_values(["Alturas"], ascending=False)

fig = plt.figure()
ax = plt.axes()

bar_chart = plt.bar(df.index, df.Alturas, color='#00a2a1')
ax.bar_label(bar_chart, label_type='center', color='white')

plt.xlabel('Nombres')
plt.ylabel('Alturas (m)')
plt.title('Ejercicio 7')
plt.show()

# %% [markdown]
# 8. Cambia el tamaño de la figura a (3,5)

# %%
alturas = [1.6, 1.8, 1.75, 1.9, 1.7]
nombres = ['ana', 'luis', 'pedro', 'sofia', 'carmen']

fig = plt.figure(figsize=(3,5))

plt.bar(nombres, alturas, color='#00a2a1')
plt.xlabel('Nombres')
plt.ylabel('Alturas (m)')
plt.title('Ejercicio 8 (figsize(3,5))')
plt.show()

# %% [markdown]
# 9. Basándote en el gráfico anterior, borra la escala del eje Y (ya aparece en la altura)
# Pista: cuando plt.yticks() recibe una lista vacía no pinta el eje Y

# %%
alturas = [1.6, 1.8, 1.75, 1.9, 1.7]
nombres = ['ana', 'luis', 'pedro', 'sofia', 'carmen']

ax = plt.axes()
bar_chart = plt.bar(nombres, alturas, color='#00a2a1')
ax.bar_label(bar_chart, label_type='center', color='white')

ax.set_yticks([])
plt.xlabel('Nombres')
plt.ylabel('Alturas (m)')
plt.title('Ejercicio 9')
plt.show()

# %% [markdown]
# 10. Prueba a hacer el gráfico con las barras en horizontal.

# %%
alturas = [1.6, 1.8, 1.75, 1.9, 1.7]
nombres = ['ana', 'luis', 'pedro', 'sofia', 'carmen']

ax = plt.axes()
bar_chart = plt.barh(nombres, alturas, color='#00a2a1')
# ax.barh(y_pos, performance, xerr=error, align='center')
ax.bar_label(bar_chart, label_type='center', color='white')

ax.set_xticks([])
plt.ylabel('Nombres')
plt.xlabel('Alturas (m)')
plt.title('Ejercicio 10')
plt.show()

# %% [markdown]
# 11. Prueba a invertir los ejes con ax.invert_axis()
# Necesitarás tener los ejes disponibles fuera de la figura

# %%
alturas = [1.6, 1.8, 1.75, 1.9, 1.7]
nombres = ['ana', 'luis', 'pedro', 'sofia', 'carmen']

ax = plt.axes()
bar_chart = plt.barh(nombres, alturas, color='#00a2a1')
# ax.barh(y_pos, performance, xerr=error, align='center')
ax.bar_label(bar_chart, label_type='center', color='white')
ax.invert_yaxis()
ax.invert_xaxis()

ax.set_xticks([])
plt.ylabel('Nombres')
plt.xlabel('Alturas (m)')
plt.title('Ejercicio 11')
plt.show()

# %% [markdown]
# 12. En el último gráfico, cambia el estilo a 'dark_background'

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
alturas = [1.6, 1.8, 1.75, 1.9, 1.7]
nombres = ['ana', 'luis', 'pedro', 'sofia', 'carmen']

plt.style.use('dark_background')

ax = plt.axes()
bar_chart = plt.barh(nombres, alturas, color='#00a2a1')
# ax.barh(y_pos, performance, xerr=error, align='center')
ax.bar_label(bar_chart, label_type='center', color='white')
ax.invert_yaxis()
ax.invert_xaxis()

ax.set_xticks([])
plt.ylabel('Nombres')
plt.xlabel('Alturas (m)')
plt.title('Ejercicio 12')
plt.show()

# %% [markdown]
# 13. Vamos a introducir pandas. Crea un DataFrame con las columnas "Year" de valores 2015, 2016, 2017, 2018, 2019 y la columna "Sold_items_A" de valores 1000, 3500, 4000, 5500, 7000

# %%
year = [2015, 2016, 2017, 2018, 2019]
sold_items_A = [1000, 3500, 4000, 5500, 7000]

df = pd.DataFrame({
    'Year': year,
    'Sold_items_A':sold_items_A
})

df
# Out:
#    Year  Sold_items_A
# 0  2015          1000
# 1  2016          3500
# 2  2017          4000
# 3  2018          5500
# 4  2019          7000

# %%
df.dtypes
# Out:
# Year            int64
# Sold_items_A    int64
# dtype: object

# %% [markdown]
# 14. Ahora pintamos un gráfico de línea con las ventas respecto al año. Pon un título y etiquetas en los ejes.
# Cambia el estilo a 'seaborn-white'. La línea debe ser con rayas y verde.

# %%
plt.style.use('seaborn-v0_8-white')

fig = plt.figure()
ax = plt.axes()

ax.plot(df.Year.astype(int), df.Sold_items_A, '--g');
# ax.set_xticklabels(df['Year']) NO FUNCIONA BIEN
plt.xticks(df.Year)
plt.title('Ejercicio 14')
plt.ylabel('Sold Items A')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# 15. Otro departamento B ha vendido en esos años 2000, 3100, 5000, 4000, 6000 unidades. Incluye esa columna en el DataFrame y pinta en la misma gráfica las dos líneas. B es una línea punteada y roja. Muestra una leyenda abajo a la derecha.

# %%
b = [2000, 3100, 5000, 4000, 6000]
df['Sold_items_B'] = b
df
# Out:
#    Year  Sold_items_A  Sold_items_B
# 0  2015          1000          2000
# 1  2016          3500          3100
# 2  2017          4000          5000
# 3  2018          5500          4000
# 4  2019          7000          6000

# %%
plt.style.use('seaborn-v0_8-white')

fig = plt.figure(figsize=(8, 6))
ax = plt.axes()

ax.plot(df.Year.astype(int), df.Sold_items_A, '--g', label = 'Sold Items A');
ax.plot(df.Year.astype(int), df.Sold_items_B, ':r', label = 'Sold Items B');
ax.legend(loc='lower right', fontsize = 12)
# ax.set_xticklabels(df['Year'].astype(int))
plt.xticks(df.Year)
plt.title('Ejercicio 15')
plt.ylabel('Sold Items')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# 16. Haz un scatter del departamento A usando __solo el DataFrame__.
# Pista: el propio DataFrame tiene un método plot.
# df.plot('columna X', 'columna Y', 'kind' = 'scatter)

# %%
plt.style.use('seaborn-v0_8-white')

df.plot(x='Year', y='Sold_items_A', kind='scatter', color='#CBC3E3', \
        xlabel = 'Year', ylabel = 'Sold Item A', \
         title='Ejercicio 16: Scatter of Sold Items A');
plt.xticks(df.Year)
plt.show()

# %% [markdown]
# 17. Prueba a cambiar kind a 'pie'

# %%
plt.style.use('seaborn-v0_8-pastel')

df.plot(x='Year', y='Sold_items_A', kind='pie', color='#CBC3E3', \
        xlabel = 'Year', ylabel = 'Sold Item A', \
         title='Ejercicio 17: Scatter of Sold Items A');
plt.show()

# %% [markdown]
# 18. Prueba a quitar la leyenda incluyendo legend igual a False, añade labels y quita la etiqueta en Y

# %%
plt.style.use('seaborn-v0_8-pastel')

df.plot(x='Year', y='Sold_items_A', kind='pie', color='#CBC3E3', \
        xlabel = 'Year', ylabel = '', \
        title='Ejercicio 18: Scatter of Sold Items A', \
        legend = False);
plt.show()

# %%
# pintar año y cantidades en el label
plt.style.use('seaborn-v0_8-pastel')
df.set_index('Year')['Sold_items_A'].plot(
    kind='pie',
    autopct='%1.1f%%',         # para que salga porcentaje
    ylabel='',                 
    title='Ejercicio 18: Pie chart of Sold Items A',
    legend=False,
    # colormap='viridis'        
)

# plt.ylabel('')  # A veces hay que repetirlo para limpiar del todo
plt.show()

# %% [markdown]
# 19. Vamos a pintar un histograma de unas alturas generadas aleatoriamente. Crea 300 alturas entre 150 y 190 cm.

# %%
plt.style.use('seaborn-v0_8')

heights = np.random.randint(150, 191, size=300)

plt.hist(heights, bins=40);

# %%
plt.style.use('seaborn-v0_8')

heights = np.random.randint(150, 191, size=300)

df_19 = pd.DataFrame({"Alturas": heights})

df_19.plot(bins=40, kind='hist', figsize=(10,5))

# plt.hist(heights, bins=40);
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Pista: https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html
