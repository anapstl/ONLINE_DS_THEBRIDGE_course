# %% [markdown]
# ## Web scrapping de IMDB

# %% [markdown]
# Descarga la información correspondiente y guarda en un csv el top de las 250 películas mediante webscrapping. Encapsúlalo en un script.
#
# Obtén:
# * Título
# * Año
# * Duración
# * Posición
# * Rating

# %%
# Si la petición te devuelve un 403, puedes probar con:
# pip install fake-useragent
# from fake_useragent import UserAgent
# ua = UserAgent()
# headers = {'User-Agent': ua.random}
# response = requests.get(url, headers=headers)

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import json

# %%
url = "https://www.imdb.com/es-es/chart/top/"
# response = requests.get(url)
# response

# %%
from fake_useragent import UserAgent
ua = UserAgent()
headers = {'User-Agent': ua.random}
response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
html = response.content
print(html)
# Out:
# b'<!DOCTYPE html><html lang="es-ES" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://www.facebook.com/2008/fbml"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>window.addEventListener(\'load\', (event) => {\n        if (typeof window.csa !== \'undefined\' && typeof window.csa === \'function\') {\n            var csaLatencyPlugin = window.csa(\'Content\', {\n                element: {\n                    slotId: \'LoadTitle\',\n                    type: \'service-call\'\n                }\n            });\n            csaLatencyPlugin(\'mark\', \'clickToBodyBegin\', 1747817512785);\n        }\n    })</script><title>Las 250 mejores pel\xc3\xadculas de IMDb</title><meta name="description" content="Seg\xc3\xban la calificaci\xc3\xb3n de los votantes habituales de IMDb." data-id="main"/><meta name="google-site-verification" content="0cadf7898134e79b"/><meta name="msvalidate.01" content="C1DACEF2769068C0B0D2687C9E5105FA"/><meta name="robots" content="max-image-preview:large"/><script type="application/ld+json">{"@type":"ItemList","itemListElement":[{"@type":"ListItem","item":{"@type":"Movie","url":"https://www.imdb.com/es-es/title/tt0111161/","name":"The Shawshank Redemption","alternateName":"Cadena perpetua","description":"Andy Dufresne es encarcelado por matar a su esposa y al amante de esta. Tras una dura adaptaci\xc3\xb3n, intenta mejorar las condiciones de la prisi\xc3\xb3n y dar esperanza a sus compa\xc3\xb1eros.","image":"https://m.media-amazon.com/images/M/MV5BMTA1MjE0Nzk4MDleQTJeQWpwZ15BbWU4MDA0NjIxMjAx._V1_.jpg","aggregateRating":{"@type":"AggregateRating","bestRating":10,"worstRating":1,"ratingValue":9.3,"ratingCount":3045590},"contentRating":"13","genre":"Drama","duration":"PT2H22M"}},{"@type":"ListItem","item":{"@type":"Movie","url":"https://www.imdb.com/es-es/title/tt0068646/","name":"The Godfather","alternateName":"El padrino","description":"El envejecido patriarca de una dinast\xc3\xada del crimen organizado en la ciudad de Nueva York de la posguerra transfiere el control de su imperio clandestino a su reacio hijo menor.","image":"https://m.media-amazon.com/images/M/MV5BNTljNjllNDAtMzc0MS00ZGExLThlOTktOTRlNzc3YjA3ZWFlXkEyXkFqcGc@._V1_.jpg","aggregateRating":{"@type":"AggregateRating","bestRating":10,"worstRating":1,"ratingValue":9.2,"ratingCount":2126064},"contentRating":"18","genre":"Crimen, Drama","duration":"PT2H55M"}},{"@type":"ListItem","item":{"@type":"Movie","url":"https://www.imdb.com/es-es/title/tt0468569/","name":"The Dark Knight","alternateName":"El caballero oscuro","description":"Cuando la amenaza conocida como el Joker causa estragos y el caos en Gotham City, Batman debe aceptar una de las mayores pruebas psicol\xc3\xb3gicas y f\xc3\xadsicas para luchar contra la injusticia.","image":"https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_.jpg","aggregateRating":{"@type":"AggregateRating","bestRating":10,"worstRating":1,"ratingValue":9,"ratingCount":3022443},"contentRating":"13","genre":"Acci\xc3\xb3n, Crimen, Drama","duration":"PT2H32M"}},{"@type":"ListItem","item":{"@type":"Movie","url":"https://www.imdb.com/es-es/title/tt0071562/","name":"The Godfather Part II","alternateName":"El padrino parte II","description":"Se retratan los inicios de la vida y la carrera de Vito Corleone en el Nueva York de los a\xc3\xb1os 20, mientras su hijo, Michael, ampl\xc3\xada y refuerza su control sobre el sindicato del crimen familiar.","image":"https://m.media-amazon.com/images/M/MV5BMjQ5MzQxZTEtMmE1Yy00NjZlLTk5ODItNjI3MWIxMjk1M2U5XkEyXkFqcGc@._V1_.jpg","aggregateRating":{"@type":"AggregateRating","bestRating":10,"worstRating":1,"ratingValue":9,"ratingCount":1430228},"contentRating":"18","genre":"Crimen, Drama","duration":"PT3H22M"}},{"@type":"ListItem","item":{"@type":"Movie","url":"https://www.imdb.com/es-es/title/tt0050083/","name":"12 A ...

# %%
soup = bs(html, 'html.parser')
# print(soup)

# %%
soup.title
# Out:
# <title>Las 250 mejores películas de IMDb</title>

# %%
movies_str = soup.find("script", type="application/ld+json")
movies_json = json.loads(movies_str.string)
movies_json
# Out:
# {'@type': 'ItemList',
#  'itemListElement': [{'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0111161/',
#     'name': 'The Shawshank Redemption',
#     'alternateName': 'Cadena perpetua',
#     'description': 'Andy Dufresne es encarcelado por matar a su esposa y al amante de esta. Tras una dura adaptación, intenta mejorar las condiciones de la prisión y dar esperanza a sus compañeros.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMTA1MjE0Nzk4MDleQTJeQWpwZ15BbWU4MDA0NjIxMjAx._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 9.3,
#      'ratingCount': 3045590},
#     'contentRating': '13',
#     'genre': 'Drama',
#     'duration': 'PT2H22M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0068646/',
#     'name': 'The Godfather',
#     'alternateName': 'El padrino',
#     'description': 'El envejecido patriarca de una dinastía del crimen organizado en la ciudad de Nueva York de la posguerra transfiere el control de su imperio clandestino a su reacio hijo menor.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNTljNjllNDAtMzc0MS00ZGExLThlOTktOTRlNzc3YjA3ZWFlXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 9.2,
#      'ratingCount': 2126064},
#     'contentRating': '18',
#     'genre': 'Crimen, Drama',
#     'duration': 'PT2H55M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0468569/',
#     'name': 'The Dark Knight',
#     'alternateName': 'El caballero oscuro',
#     'description': 'Cuando la amenaza conocida como el Joker causa estragos y el caos en Gotham City, Batman debe aceptar una de las mayores pruebas psicológicas y físicas para luchar contra la injusticia.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 9,
#      'ratingCount': 3022443},
#     'contentRating': '13',
#     'genre': 'Acción, Crimen, Drama',
#     'duration': 'PT2H32M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0071562/',
#     'name': 'The Godfather Part II',
#     'alternateName': 'El padrino parte II',
#     'description': 'Se retratan los inicios de la vida y la carrera de Vito Corleone en el Nueva York de los años 20, mientras su hijo, Michael, amplía y refuerza su control sobre el sindicato del crimen familiar.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjQ5MzQxZTEtMmE1Yy00NjZlLTk5ODItNjI3MWIxMjk1M2U5XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 9,
#      'ratingCount': 1430228},
#     'contentRating': '18',
#     'genre': 'Crimen, Drama',
#     'duration': 'PT3H22M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0050083/',
#     'name': '12 Angry Men',
#     'alternateName': '12 hombres sin piedad',
#     'description': 'Un miembro del jurado trata de evitar un error judicial obligando al resto del jurado a reconsiderar las pruebas.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYThhOGFhODktNGEwNi00MzY2LTg3YWYtNzAzZTE0MTFlMWQxXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 9,
#      'ratingCount': 925964},
#     'contentRating': 'A',
#     'genre': 'Crimen, Drama',
#     'duration': 'PT1H36M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0167260/',
#     'name': 'The Lord of the Rings: The Return of the King',
#     'alternateName': 'El señor de los anillos: El retorno del rey',
#     'description': 'Gandalf y Aragorn lideran el mundo de los hombres contra la armada de Sauron para distraer su atención de Frodo y Sam, quienes se aproximan al Monte del Destino con el Anillo Único.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZGEzZDkzNDgtMGMzZi00NjNhLTliNWMtMTllYzQ2OTQwNGFkXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 9,
#      'ratingCount': 2078873},
#     'contentRating': '13',
#     'genre': 'Aventura, Drama, Fantasía',
#     'duration': 'PT3H21M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0108052/',
#     'name': 'Schindler&apos;s List',
#     'alternateName': 'La lista de Schindler',
#     'description': 'En la Polonia ocupada por los alemanes durante la Segunda Guerra Mundial, el industrial Oskar Schindler se preocupa por sus trabajadores judíos tras presenciar su persecución por los nazis.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZWUyNTJmOTMtZGM4MC00NWE2LThmZTUtZWE1NGM2YzYwZjRlXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 9,
#      'ratingCount': 1523386},
#     'contentRating': '13',
#     'genre': 'Biografía, Drama, Historia',
#     'duration': 'PT3H15M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0110912/',
#     'name': 'Pulp Fiction',
#     'description': 'Las vidas de dos mafiosos, un boxeador, la esposa de un gánster y un par de bandidos se entrelazan en cuatro historias de violencia y redención.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMzNlNGRkZWYtNmE0Yy00NjQyLWFmMzItYWY5NGM2YWU4OWYwXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.9,
#      'ratingCount': 2335919},
#     'contentRating': '18',
#     'genre': 'Crimen, Drama',
#     'duration': 'PT2H34M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0120737/',
#     'name': 'The Lord of the Rings: The Fellowship of the Ring',
#     'alternateName': 'El señor de los anillos: La comunidad del anillo',
#     'description': 'Un hobbit de la Comarca y ocho compañeros emprenden un viaje para destruir el poderoso Anillo Único y salvar la Tierra Media del Señor Oscuro Sauron.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNDM0ZTRjNDAtMWFiOS00MjZiLThhZjYtNGQ0ODQ5MGE3Y2Y0XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.9,
#      'ratingCount': 2108885},
#     'contentRating': '12',
#     'genre': 'Aventura, Drama, Fantasía',
#     'duration': 'PT2H58M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0060196/',
#     'name': 'Il buono, il brutto, il cattivo',
#     'alternateName': 'El bueno, el feo y el malo',
#     'description': 'Durante la guerra de Secesión, tres cazarrecompensas se lanzan a la búsqueda de un tesoro que ninguno puede localizar sin la ayuda de los otros dos.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BN2FmNmM5OTUtODEwMC00NDE5LWI4ZTUtZTg1ZmZlYjVjN2EyXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.8,
#      'ratingCount': 853718},
#     'contentRating': '14',
#     'genre': 'Aventura, Del oeste',
#     'duration': 'PT3H2M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0109830/',
#     'name': 'Forrest Gump',
#     'description': 'Las presidencias de Kennedy y Johnson, los acontecimientos de Vietnam, el Watergate y otros eventos históricos se desarrollan a través de la perspectiva de un hombre de Alabama con un coeficiente intelectual de 75.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BOWQ0NzQ5MDItYTA3Yy00Y2ZjLWFlMGQtNjcxYzU4MWM3NzFmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.8,
#      'ratingCount': 2380426},
#     'contentRating': 'A',
#     'genre': 'Drama, Romance',
#     'duration': 'PT2H22M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0167261/',
#     'name': 'The Lord of the Rings: The Two Towers',
#     'alternateName': 'El señor de los anillos: Las dos torres',
#     'description': 'Mientras Frodo y Sam se acercan a Mordor con la ayuda del astuto Gollum, la comunidad dividida se enfrenta al nuevo aliado de Sauron, Saruman, y a sus hordas de Isengard.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNjJhZjZlNjktZTEwYi00MmMwLTgyYTgtYmMyMmRlOWMzNmRjXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.8,
#      'ratingCount': 1874455},
#     'contentRating': '13',
#     'genre': 'Aventura, Drama, Fantasía',
#     'duration': 'PT2H59M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0137523/',
#     'name': 'Fight Club',
#     'alternateName': 'El club de la lucha',
#     'description': 'Un oficinista insomne y un fabricante de jabones forman un club de lucha clandestino que se convierte en mucho más.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZjA1YzQ3MDktYzRjMi00NWQ0LWFhYWYtZGMyODcwNGEwZjNmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.8,
#      'ratingCount': 2466667},
#     'contentRating': '18',
#     'genre': 'Crimen, Drama, Suspense',
#     'duration': 'PT2H19M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt1375666/',
#     'name': 'Inception',
#     'alternateName': 'Origen',
#     'description': 'A un ladrón que roba secretos corporativos a través del uso de la tecnología de compartir sueños, se le da la tarea de implantar una idea en la mente de un jefe de una gran empresa.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNTQxYmM1NzQtY2FiZS00MzRhLTljZDYtZjRmMGNiMWI3NTQxXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.8,
#      'ratingCount': 2684780},
#     'contentRating': '12',
#     'genre': 'Acción, Aventura, Ciencia ficción',
#     'duration': 'PT2H28M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0080684/',
#     'name': 'Star Wars: Episode V - The Empire Strikes Back',
#     'alternateName': 'El imperio contraataca',
#     'description': 'Tras ser brutalmente dominados los rebeldes por el Imperio en el planeta helado Hoth, Luke Skywalker comienza su entrenamiento jedi con Yoda, mientras sus amigos son perseguidos por Darth Vader y el cazarrecompensas Boba Fett.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZWQyNTJkMTAtZWQ0Zi00NGFlLWI2ZDktNTA4MzM5NDQ0MTk4XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.7,
#      'ratingCount': 1442625},
#     'contentRating': 'A',
#     'genre': 'Acción, Aventura, Fantasía',
#     'duration': 'PT2H4M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0133093/',
#     'name': 'The Matrix',
#     'alternateName': 'Matrix',
#     'description': 'Cuando una bella desconocida lleva al hacker Neo a un inframundo prohibido, descubre la impactante verdad: la vida que conoce es un elaborado engaño de una ciberinteligencia malvada.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNGE1YzI4NzMtZTUxNi00Y2I5LTg2MmQtODE0NThmYTFmMDk0XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.7,
#      'ratingCount': 2156806},
#     'contentRating': '18',
#     'genre': 'Acción, Ciencia ficción',
#     'duration': 'PT2H16M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0099685/',
#     'name': 'GoodFellas',
#     'alternateName': 'Uno de los nuestros',
#     'description': 'La historia de Henry Hill y su vida en la mafia, abarcando su relación con su esposa Karen Hill y sus socios mafiosos Jimmy Conway y Tommy DeVito en el sindicato del crimen italoamericano.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYTE0MmJhNGUtZDI5My00YThhLTk1NmItNDExOWUxMjg1YzUxXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.7,
#      'ratingCount': 1326790},
#     'contentRating': '18',
#     'genre': 'Biografía, Crimen, Drama',
#     'duration': 'PT2H25M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0816692/',
#     'name': 'Interstellar',
#     'description': 'Un equipo de exploradores viaja a través de un agujero de gusano en el espacio en un intento de garantizar la supervivencia de la humanidad.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYzdjMDAxZGItMjI2My00ODA1LTlkNzItOWFjMDU5ZDJlYWY3XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.7,
#      'ratingCount': 2346977},
#     'contentRating': '12',
#     'genre': 'Aventura, Drama, Ciencia ficción',
#     'duration': 'PT2H49M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0073486/',
#     'name': 'One Flew Over the Cuckoo&apos;s Nest',
#     'alternateName': 'Alguien voló sobre el nido del cuco',
#     'description': 'Un criminal alega locura para ser enviado a un centro de salud mental, donde se rebela contra la opresiva enfermera y moviliza a los pacientes, a quienes tienen atemorizados.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYjdkNjdlNDgtZTM1My00YzEwLTk5YjItYjE3YzllZTViNTVlXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.7,
#      'ratingCount': 1117157},
#     'contentRating': '18',
#     'genre': 'Drama',
#     'duration': 'PT2H13M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0114369/',
#     'name': 'Se7en',
#     'alternateName': 'Seven',
#     'description': 'Dos detectives, un novato y un veterano, dan caza a un asesino en serie cuyo móvil son los siete pecados capitales.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjk4YWQ5YTItZTk2OS00MTcxLWIwNjctZjE3NzNhNjQzZjI2XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 1912593},
#     'contentRating': '18',
#     'genre': 'Crimen, Drama, Misterio',
#     'duration': 'PT2H7M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0038650/',
#     'name': 'It&apos;s a Wonderful Life',
#     'alternateName': 'Qué bello es vivir',
#     'description': 'Un ángel es enviado desde el cielo para ayudar a un hombre de negocios desesperadamente frustrado, mostrándole cómo habría sido la vida si él nunca hubiera existido.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BOWIzZDkwM2MtMWU5Yy00NzA5LWFhMzUtMmI1Yzc4NWQzMzg2XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 527946},
#     'contentRating': 'A',
#     'genre': 'Drama, Familiar, Fantasía',
#     'duration': 'PT2H10M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0102926/',
#     'name': 'The Silence of the Lambs',
#     'alternateName': 'El silencio de los corderos',
#     'description': 'Una joven cadete del FBI busca la ayuda de un asesino caníbal y manipulador encarcelado con el fin de atrapar a otro asesino en serie, un loco que despelleja a sus víctimas.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BOGZiZjYxY2UtNDE5YS00NzcwLWI0NmItNjcwYThkOWMwYTdhXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 1636422},
#     'contentRating': '18',
#     'genre': 'Crimen, Drama, Terror',
#     'duration': 'PT1H58M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0047478/',
#     'name': 'Shichinin no samurai',
#     'alternateName': 'Los siete samuráis',
#     'description': 'Un pueblo pobre atacado por bandidos recluta a siete samuráis desempleados para que les ayuden a defenderse.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYzc0ODMyMzctZTA5Zi00MGZhLWE0NTItZjJhOTE3OWMxZjBlXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 384270},
#     'contentRating': 'A',
#     'genre': 'Acción, Drama',
#     'duration': 'PT3H27M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0120815/',
#     'name': 'Saving Private Ryan',
#     'alternateName': 'Salvar al soldado Ryan',
#     'description': 'Tras el desembarco de Normandía, un grupo de soldados estadounidenses cruza las líneas enemigas para rescatar a un paracaidista cuyos hermanos han muerto en combate.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMzU0YTgzM2EtYWNmMy00NWM1LWE0NTMtYjFhZDNlMDU1NWJmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 1570738},
#     'contentRating': '13',
#     'genre': 'Drama, Bélico',
#     'duration': 'PT2H49M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0317248/',
#     'name': 'Cidade de Deus',
#     'alternateName': 'Ciudad de Dios',
#     'description': 'En un barrio pobre de Rio, los caminos de dos niños se cruzan mientras uno quiere ser fotógrafo y el otro capo.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYjY4NGI5OTUtY2ZlZS00Zjk4LTk5N2MtN2JmYWVjNGNmMGRlXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 837826},
#     'contentRating': '18',
#     'genre': 'Crimen, Drama',
#     'duration': 'PT2H10M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0120689/',
#     'name': 'The Green Mile',
#     'alternateName': 'La milla verde',
#     'description': 'Las vidas de los guardias del corredor de la muerte se ven afectadas por uno de sus reclusos: un hombre negro acusado de asesinato y violación de niños, pero que tiene un misterioso don.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BM2VlMDA2NWYtYzQxZi00NGIyLTk0OTYtMGY3ODFmOGFhMTI3XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 1486550},
#     'contentRating': '13',
#     'genre': 'Crimen, Drama, Fantasía',
#     'duration': 'PT3H9M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0118799/',
#     'name': 'La vita è bella',
#     'alternateName': 'La vida es bella',
#     'description': 'Cuando un bibliotecario judío y su hijo se convierten en víctimas del Holocausto, él usará una perfecta mezcla de voluntad, humor e imaginación para proteger a su hijo de los peligros en el campo de concentración.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNTZhN2IwZWUtNTI2Yy00OWNjLWExZmYtOGMzN2M5NTE1MzM1XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 778723},
#     'contentRating': 'A',
#     'genre': 'Comedia, Drama, Romance',
#     'duration': 'PT1H56M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0103064/',
#     'name': 'Terminator 2: Judgment Day',
#     'alternateName': 'Terminator 2: El juicio final',
#     'description': 'Un cyborg, idéntico al que fracasó en su intento de matar a Sarah Connor, debe proteger ahora a su hijo adolescente John de un cyborg más avanzado y poderoso.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BM2U1MTc3M2EtYzhjYy00MmRkLWExZDEtZmI0OWNjMTFkODlmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 1233265},
#     'contentRating': '18',
#     'genre': 'Acción, Aventura, Ciencia ficción',
#     'duration': 'PT2H17M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0076759/',
#     'name': 'Star Wars',
#     'alternateName': 'La guerra de las galaxias',
#     'description': 'Luke Skywalker une sus fuerzas con un caballero jedi, un piloto fanfarrón, un wookiee y dos droides para salvar a la galaxia de la estación espacial del Imperio, a la vez que intenta rescatar a la princesa Leia del malvado Darth V...',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNGU3YTdiM2EtY2Y3MC00NTIzLWEzYzYtM2IxZDNhZjkwNjU1XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 1509804},
#     'contentRating': 'A',
#     'genre': 'Acción, Aventura, Fantasía',
#     'duration': 'PT2H1M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0088763/',
#     'name': 'Back to the Future',
#     'alternateName': 'Regreso al futuro',
#     'description': 'Marty McFly, un estudiante de secundaria de 17 años, es enviado accidentalmente treinta años al pasado en un DeLorean que viaja en el tiempo, inventado por su gran amigo, el excéntrico científico Doc Brown.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNzVhMDRlMzctMjgxOC00MDllLTkzZWUtZTk4ODgyNDgwZTBmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1378558},
#     'contentRating': 'A',
#     'genre': 'Aventura, Comedia, Ciencia ficción',
#     'duration': 'PT1H56M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0245429/',
#     'name': 'Sen to Chihiro no kamikakushi',
#     'alternateName': 'El viaje de Chihiro',
#     'description': 'Durante el traslado de su familia a los suburbios, una niña de 10 años de edad deambula por un mundo gobernado por dioses, brujas y espíritus, y donde los humanos se convierten en bestias.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMWI1OTdjN2EtOGUxYy00ZDBmLWFlNzAtNmRkZjhiMTIzOTNhXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 911046},
#     'contentRating': 'A',
#     'genre': 'Animación, Aventura, Familiar',
#     'duration': 'PT2H4M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0253474/',
#     'name': 'The Pianist',
#     'alternateName': 'El pianista',
#     'description': 'Un músico judío polaco lucha por sobrevivir a la destrucción del gueto de Varsovia durante la Segunda Guerra Mundial.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjEwNmEwYjgtNTk3ZC00NjljLTg5ZDctZTY3ZGQwZjRkZmQxXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 968826},
#     'contentRating': '13',
#     'genre': 'Biografía, Drama, Música',
#     'duration': 'PT2H30M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0172495/',
#     'name': 'Gladiator',
#     'alternateName': 'Gladiator (El gladiador)',
#     'description': 'Un exgeneral romano se propone vengarse del emperador corrupto que asesinó a su familia y lo envió a la esclavitud.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZDZlZjY4NGMtNWIwNC00OWVhLTkyMmUtODI5ZDY4MmFhODllXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1760960},
#     'contentRating': '13',
#     'genre': 'Acción, Aventura, Drama',
#     'duration': 'PT2H35M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt6751668/',
#     'name': 'Gisaengchung',
#     'alternateName': 'Parásitos',
#     'description': 'La familia Ki-taek, todos desempleados, se ve envuelta en un incidente con la rica y glamurosa familia Parks.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYjk1Y2U4MjQtY2ZiNS00OWQyLWI3MmYtZWUwNmRjYWRiNWNhXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1063671},
#     'contentRating': '16',
#     'genre': 'Drama, Suspense',
#     'duration': 'PT2H12M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0054215/',
#     'name': 'Psycho',
#     'alternateName': 'Psicosis',
#     'description': 'Una secretaria de Phoenix malversa cuarenta mil dólares de un cliente, se da a la fuga y se registra en un motel remoto administrado por un joven con una controladora madre.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BOTUxZGRkZjQtMGFjOS00YTZkLTg5MmItOGRhMjE3YjQyMjBmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 752942},
#     'contentRating': '16',
#     'genre': 'Drama, Terror, Misterio',
#     'duration': 'PT1H49M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0110357/',
#     'name': 'The Lion King',
#     'alternateName': 'El rey león',
#     'description': 'El pequeño león Simba, príncipe heredero, es engañado por su malvado tío, quien desea el trono para sí mismo.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BOTk0YjM0YmMtZTNiOC00ZjU5LWEzNmUtNTRiYzAxMTg0MzVkXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1204140},
#     'contentRating': 'A',
#     'genre': 'Animación, Aventura, Drama',
#     'duration': 'PT1H28M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0095327/',
#     'name': 'Hotaru no haka',
#     'alternateName': 'La tumba de las luciérnagas',
#     'description': 'Un chico y su hermana pequeña intentan sobrevivir en Japón durante la Segunda Guerra Mundial.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BOTBlY2ViYmQtOWIzYy00NDRjLTg4ZDgtNWJiYWU1MjNlMDcwXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 349619},
#     'contentRating': '13',
#     'genre': 'Animación, Drama, Bélico',
#     'duration': 'PT1H28M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0407887/',
#     'name': 'The Departed',
#     'alternateName': 'Infiltrados',
#     'description': 'Un policía de incógnito y un topo en el departamento de policía intentan identificarse el uno al otro mientras se infiltran en una banda irlandesa en el sur de Boston.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYjhhMWVjMTUtM2EyMi00ZTU4LWIzNmYtZjMyNzJiMmZjMWRmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1488613},
#     'contentRating': '18',
#     'genre': 'Crimen, Drama, Suspense',
#     'duration': 'PT2H31M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt2582802/',
#     'name': 'Whiplash',
#     'description': 'Un joven y prometedor batería se inscribe en un competitivo conservatorio donde sus sueños de grandeza son guiados por un instructor que no se detiene ante nada para realizar el potencial de su estudiante.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjM0NmUzOWUtN2I0Mi00NTRiLWJmNzItZDE2YWIwNDIwNmEzXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1075047},
#     'contentRating': '12',
#     'genre': 'Drama, Música',
#     'duration': 'PT1H46M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0056058/',
#     'name': 'Seppuku',
#     'alternateName': 'Harakiri',
#     'description': 'Un viejo samurái ronin llega a la casa de un señor feudal y pide un lugar honorable donde poder suicidarse. Pero cuando el ronin pregunta por un samurái más joven que llegó antes que él, los acontecimientos toman un rumbo inesperado.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZThiZjU5ZDQtZDI4Mi00ZGYyLTkzOTktYmIzZTFlZTkxYzg5XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 79737},
#     'contentRating': '13',
#     'genre': 'Drama, Misterio',
#     'duration': 'PT2H13M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0482571/',
#     'name': 'The Prestige',
#     'alternateName': 'El truco final (El prestigio)',
#     'description': 'Tras un trágico accidente, dos magos en el Londres de 1890 se enfrentan para crear la ilusión definitiva, mientras sacrifican todo lo que tienen para superar al otro.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjUxYzNmOWItZjc1NS00OTUxLTgzODEtODU2NGEzMDJmYWFjXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1515484},
#     'contentRating': '18',
#     'genre': 'Drama, Misterio, Ciencia ficción',
#     'duration': 'PT2H10M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0120586/',
#     'name': 'American History X',
#     'description': 'Un exmilitante de los skinheads neonazis intenta disuadir a su hermano pequeño de tomar las mismas malas decisiones que él tomó.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjU3OWQ2MWQtZTMzNS00MGRjLWE3MmQtZmQ1Mzc0MGY3NmQyXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1231577},
#     'contentRating': '13',
#     'genre': 'Crimen, Drama',
#     'duration': 'PT1H59M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0110413/',
#     'name': 'Léon',
#     'alternateName': 'El profesional (Léon)',
#     'description': 'Leon, un asesino a sueldo profesional, se hace cargo con recelo de Matilda, una niña de 12 años, cuando su familia es asesinada. Leon y Matilda entablan una inusual relación cuando ella se convierte en su protegida y aprende el of...',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNGRkYTNhOWQtYmI0Ni00MjZhLWJmMzAtMTA2Mjg4NGNiNDU0XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1303359},
#     'contentRating': '18',
#     'genre': 'Acción, Crimen, Drama',
#     'duration': 'PT1H50M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt9362722/',
#     'name': 'Spider-Man: Across the Spider-Verse',
#     'alternateName': 'Spider-Man: Cruzando el multiverso',
#     'description': 'Miles Morales conoce a un nuevo equipo de Spider-People formado por héroes de diferentes dimensiones. Pero cuando los héroes se enfrentan sobre cómo hacer frente a una nueva amenaza, Miles se encuentra en una encrucijada.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BODRiZGQyOGEtZWE1OS00MjQ2LWFiNzUtNjgxMDg3MmM0MDNhXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 456288},
#     'contentRating': '7',
#     'genre': 'Animación, Acción, Aventura',
#     'duration': 'PT2H20M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0034583/',
#     'name': 'Casablanca',
#     'description': 'Un cínico expatriado norteamericano, dueño de un café, se debate entre ayudar o no a su antigua amante y a su marido fugitivo a escapar de los nazis en el Marruecos francés.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNTcyN2YzOTAtNDgyNi00YzA2LWIzOTAtNzg0ZjUyNjMzYWIyXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 631551},
#     'contentRating': '16',
#     'genre': 'Drama, Romance, Bélico',
#     'duration': 'PT1H42M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0114814/',
#     'name': 'The Usual Suspects',
#     'alternateName': 'Sospechosos habituales',
#     'description': 'El único superviviente de un terrible tiroteo en un barco relata los eventos que condujeron a esta masacre, empezando con cinco criminales que se encuentran aparentemente al azar en una selección policial de sospechosos habituales.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMDliMWJiOTItOTUzNi00YjdmLTgxYzItZjQyYzU1NmZhZTdiXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1190298},
#     'contentRating': '18',
#     'genre': 'Crimen, Drama, Misterio',
#     'duration': 'PT1H46M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt1675434/',
#     'name': 'Intouchables',
#     'alternateName': 'Intocable',
#     'description': 'Un accidente de parapente deja a un aristócrata cuadripléjico, quien contrata a un joven de un barrio pobre para que sea su cuidador.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BOWFmYzhiODMtZjYzOC00MTgyLWFkN2MtM2VlMDgwMzdkNGNkXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 978939},
#     'contentRating': '7',
#     'genre': 'Comedia, Drama',
#     'duration': 'PT1H52M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0095765/',
#     'name': 'Nuovo Cinema Paradiso',
#     'alternateName': 'Cinema Paradiso',
#     'description': 'Un director de cine recuerda cómo en su infancia se enamoró del cine de su pueblo y entabló una profunda amistad con el proyeccionista.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMTljNzc4YWEtYTZlMS00ODMyLWIwMTAtNWQxY2VkMDEwYTk5XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 301457},
#     'contentRating': 'A',
#     'genre': 'Drama, Romance',
#     'duration': 'PT2H54M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0078748/',
#     'name': 'Alien',
#     'alternateName': 'Alien, el octavo pasajero',
#     'description': 'La tripulación de una nave espacial comercial se encuentra con una forma de vida mortal tras investigar una transmisión desconocida.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BN2NhMDk2MmEtZDQzOC00MmY5LThhYzAtMDdjZGFjOGZjMjdjXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1016568},
#     'contentRating': '16',
#     'genre': 'Terror, Ciencia ficción',
#     'duration': 'PT1H57M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0027977/',
#     'name': 'Modern Times',
#     'alternateName': 'Tiempos modernos',
#     'description': 'Una hombre y una joven sin hogar se enfrentan a la vida moderna en las calles de la sociedad industrial.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjZmMjA4OGQtNjFmZi00ODE1LTkzM2QtYzg4OTM4ZDk2YzNkXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 273141},
#     'contentRating': '16',
#     'genre': 'Comedia, Drama, Romance',
#     'duration': 'PT1H27M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0047396/',
#     'name': 'Rear Window',
#     'alternateName': 'La ventana indiscreta',
#     'description': 'Un fotógrafo en silla de ruedas espía a sus vecinos desde la ventana de su apartamento en Greenwich Village, y se convence de que uno de ellos ha cometido un asesinato, a pesar del escepticismo de su novia, modelo de moda.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjFlZmQwNjUtYTJlOC00MjBiLWE2YTQtMDk1ZGM3YWJmZThmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 546421},
#     'contentRating': '16',
#     'genre': 'Drama, Misterio, Suspense',
#     'duration': 'PT1H52M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0064116/',
#     'name': 'C&apos;era una volta il West',
#     'alternateName': 'Hasta que llegó su hora',
#     'description': 'Un misterioso extraño con una armónica se alía con un famoso forajido para proteger a una bella viuda de un despiadado asesino que trabaja para el ferrocarril.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjEzNjg1NzEwMV5BMl5BanBnXkFtZTgwMTE4OTU0MTE@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 368409},
#     'contentRating': '18',
#     'genre': 'Drama, Del oeste',
#     'duration': 'PT2H46M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt1853728/',
#     'name': 'Django Unchained',
#     'alternateName': 'Django desencadenado',
#     'description': 'Con la ayuda de un cazarrecompensas alemán, un esclavo liberado se propone rescatar a su esposa de un brutal propietario de una plantación en Misisipi.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMTg5NzI5ODU0MV5BMl5BanBnXkFtZTcwNDcyNDY2Nw@@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1792724},
#     'contentRating': '16',
#     'genre': 'Del oeste',
#     'duration': 'PT2H45M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0021749/',
#     'name': 'City Lights',
#     'alternateName': 'Luces de la ciudad',
#     'description': 'Con la ayuda de un hombre adinerado, borracho e imprevisible, un ingenuo vagabundo que se ha enamorado de una florista ciega intenta conseguir dinero para poder proporcionarle ayuda médica.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNzIwNTQ2MDUxN15BMl5BanBnXkFtZTgwNjU2MjcyMjE@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 207103},
#     'contentRating': 'A',
#     'genre': 'Comedia, Drama, Romance',
#     'duration': 'PT1H27M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0078788/',
#     'name': 'Apocalypse Now',
#     'description': 'Un oficial del ejército estadounidense que sirve en Vietnam recibe el encargo de asesinar a un coronel renegado de las fuerzas especiales que se ve a sí mismo como un dios.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNzI4NDNlNjItMzM1Ni00YTA0LThjZTAtOTdhMGYxYmU0NmZkXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.4,
#      'ratingCount': 742513},
#     'contentRating': '16',
#     'genre': 'Drama, Misterio, Bélico',
#     'duration': 'PT2H27M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt15239678/',
#     'name': 'Dune: Part Two',
#     'alternateName': 'Dune: Parte dos',
#     'description': 'El duque Paul Atreides se une a los Fremen y comienza su entrenamiento para convertirse en Muad&apos;Dib, mientras trata de evitar el terrible futuro que ha previsto: una guerra santa en su nombre, esparciéndose por todo el universo co...',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNzBiMTQ0YjMtZDRhMC00ZDU4LTk3MDMtNWQxOGMwMjQzYjc4XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 631890},
#     'contentRating': '12',
#     'genre': 'Acción, Aventura, Drama',
#     'duration': 'PT2H46M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0910970/',
#     'name': 'WALL·E',
#     'description': 'En un futuro lejano, un pequeño robot recolector de residuos se embarca inadvertidamente en un viaje espacial que decidirá en última instancia el destino de la humanidad.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjExMTg5OTU0NF5BMl5BanBnXkFtZTcwMjMxMzMzMw@@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.4,
#      'ratingCount': 1261700},
#     'contentRating': 'A',
#     'genre': 'Animación, Aventura, Familiar',
#     'duration': 'PT1H38M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0209144/',
#     'name': 'Memento',
#     'description': 'Un hombre con pérdida de memoria a corto plazo intenta encontrar al asesino de su esposa.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYmQ3MjliNjAtNWFiZS00YWI1LTlmZTktMzBiNDE1NjRhZjU0XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.4,
#      'ratingCount': 1379517},
#     'contentRating': '13',
#     'genre': 'Misterio, Suspense',
#     'duration': 'PT1H53M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0082971/',
#     'name': 'Raiders of the Lost Ark',
#     'alternateName': 'En busca del arca perdida',
#     'description': 'En 1936, el arqueólogo y aventurero Indiana Jones es contratado por el Gobierno de Estados Unidos para encontrar el Arca de la Alianza, antes de que los nazis de Adolf Hitler puedan obtener sus impresionantes poderes.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjhkNDBiMTMtYzNlOS00OTU2LWE3ZGMtZWVmMThkZThjZjMzXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.4,
#      'ratingCount': 1074748},
#     'contentRating': 'A',
#     'genre': 'Acción, Aventura',
#     'duration': 'PT1H55M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0405094/',
#     'name': 'Das Leben der Anderen',
#     'alternateName': 'La vida de los otros',
#     'description': 'En el este de Berlín en 1984 un agente de la policía secreta vigilando a un escritor y su amante se encuentra cada vez más absorto en sus vidas.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BN2Q5M2JhZGItNTg2OC00NjQ1LTllMmYtNWUzODNhMmU3YjcxXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.4,
#      'ratingCount': 427952},
#     'contentRating': '7',
#     'genre': 'Drama, Misterio, Suspense',
#     'duration': 'PT2H17M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt4154756/',
#     'name': 'Avengers: Infinity War',
#     'alternateName': 'Vengadores: Infinity War',
#     'description': 'Los Vengadores y sus aliados estarán dispuestos a sacrificarlo todo para derrotar al poderoso Thanos antes de que su devastación y ruina ponga fin al universo.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BOGVkODYxMDEtODczZC00MjRiLTg3ZWYtZjgzN2QyMDBjZTUzXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.4,
#      'ratingCount': 1288752},
#     'contentRating': '12',
#     'genre': 'Acción, Aventura, Ciencia ficción',
#     'duration': 'PT2H29M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0043014/',
#     'name': 'Sunset Boulevard',
#     'alternateName': 'El crepúsculo de los dioses',
#     'description': 'Un guionista es contratado para reescribir el guion de una estrella de cine mudo en decadencia y acaba desarrollando una peligrosa relación.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZjNmY2FhZDUtNzMxMS00ZDFiLTlhMzEtNTBmZjUwMTIxMzQxXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.4,
#      'ratingCount': 248989},
#     'contentRating': 'Apta para mayores',
#     'genre': 'Drama, Cine negro',
#     'duration': 'PT1H50M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt4633694/',
#     'name': 'Spider-Man: Into the Spider-Verse',
#     'alternateName': 'Spider-Man: Un nuevo universo',
#     'description': 'El adolescente Miles Morales se convierte en el Spider-Man de su universo, y debe unirse a cinco individuos con poderes arácnidos de otras dimensiones para detener una amenaza para todas las realidades.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjMwNDkxMTgzOF5BMl5BanBnXkFtZTgwNTkwNTQ3NjM@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.4,
#      'ratingCount': 731649},
#     'contentRating': '7',
#     'genre': 'Animación, Acción, Aventura',
#     'duration': 'PT1H57M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0051201/',
#     'name': 'Witness for the Prosecution',
#     'alternateName': 'Testigo de cargo',
#     'description': 'Un veterano abogado británico debe defender a su cliente en un juicio por asesinato en el que surge una sorpresa tras otra.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMzEyYzNjOTktMzI5YS00MzQ4LThlOWYtZmQ4OGI0ZDk3YmVmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.4,
#      'ratingCount': 150042},
#     'contentRating': 'A',
#     'genre': 'Crimen, Drama, Misterio',
#     'duration': 'PT1H56M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0050825/',
#     'name': 'Paths of Glory',
#     'alternateName': 'Senderos de gloria',
# ...
#     'name': 'The Exorcist',
#     'alternateName': 'El exorcista',
#     'description': 'Una adolescente es poseída por una entidad malévola y su madre obtiene la ayuda de dos curas para que la liberen.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZjg3YjE4ZjAtYTdmYS00ZTBkLWE1ZjgtNzAzODUwNzRiYjlmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 478092},
#     'contentRating': '18',
#     'genre': 'Terror',
#     'duration': 'PT2H2M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0059742/',
#     'name': 'The Sound of Music',
#     'alternateName': 'Sonrisas y lágrimas',
#     'description': 'Una joven novicia es enviada por su convento en la Austria de los años 30 para convertirse en institutriz de los siete hijos de un oficial de marina viudo.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMTM2Y2QzNzUtODI5Zi00NmEzLWEyOWUtMDhhOGU4NGFkOTYyXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 276678},
#     'contentRating': 'A',
#     'genre': 'Biografía, Drama, Familiar',
#     'duration': 'PT2H52M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0019254/',
#     'name': 'La passion de Jeanne d&apos;Arc',
#     'alternateName': 'La pasión de Juana de Arco',
#     'description': 'En 1431, Juana de Arco es juzgada por herejía. Los juristas eclesiásticos intentan obligar a Juana a retractarse de sus santas visiones.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYWMwMzEyYWQtYTlmNi00MTg0LTliYjUtZTFhMTMxOGEyNjNlXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 65089},
#     'contentRating': '13',
#     'genre': 'Biografía, Drama, Historia',
#     'duration': 'PT1H50M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0032138/',
#     'name': 'The Wizard of Oz',
#     'alternateName': 'El mago de Oz',
#     'description': 'La joven Dorothy y su perro son arrastrados por un tornado desde Kansas a la mágica tierra de Oz, y se embarcan en una búsqueda con tres nuevos amigos para ver al mago, que puede devolverla a su hogar y cumplir los deseos de los d...',
#     'image': 'https://m.media-amazon.com/images/M/MV5BN2Y2ZjUzMDMtZDBkNS00OGE3LTk1NTEtZmRmODJlNzIxNDhiXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 450866},
#     'contentRating': '16',
#     'genre': 'Aventura, Familiar, Fantasía',
#     'duration': 'PT1H42M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0317705/',
#     'name': 'The Incredibles',
#     'alternateName': 'Los Increíbles',
#     'description': 'Mientras intenta llevar una tranquila vida suburbana, una familia de superhéroes encubiertos se ve obligada a entrar en acción para salvar el mundo.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNGNhMDYxNjktZjM1OS00MjI4LTgxYTAtZjIzODQ4NDVjYzU4XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8,
#      'ratingCount': 855908},
#     'contentRating': 'A',
#     'genre': 'Animación, Acción, Aventura',
#     'duration': 'PT1H55M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt1028532/',
#     'name': 'Hachi: A Dog&apos;s Tale',
#     'alternateName': 'Siempre a tu lado (Hachiko)',
#     'description': 'Un profesor universitario crea un vínculo con un perro abandonado al que acoge.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYjkxMjdlNjItZGEzMy00ZDAwLTg3MGEtZWYzYjAyZTdkYjAyXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 328611},
#     'contentRating': 'A',
#     'genre': 'Biografía, Drama, Familiar',
#     'duration': 'PT1H33M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt1979320/',
#     'name': 'Rush',
#     'description': 'La despiadada rivalidad de los años setenta en la Fórmula Uno entre James Hunt y Niki Lauda.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZTQ5NTIyNTEtMDlkNy00MTdmLWJlODktZjQ0NTU4ZjcyMDA3XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 534957},
#     'contentRating': '12',
#     'genre': 'Biografía, Drama, Deporte',
#     'duration': 'PT2H3M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0092005/',
#     'name': 'Stand by Me',
#     'alternateName': 'Cuenta conmigo',
#     'description': 'Tras la muerte de un amigo, un escritor recuerda un viaje de juventud para encontrar el cuerpo de un chico desaparecido.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjc4OTViZGEtNmIwYi00ZGM0LTliNTAtMTliNDhjMGE3NTE2XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 464753},
#     'contentRating': 'A',
#     'genre': 'Aventura, Comedia, Drama',
#     'duration': 'PT1H29M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0476735/',
#     'name': 'Babam ve Oglum',
#     'alternateName': 'Mi padre y mi hijo',
#     'description': 'La familia de un periodista de izquierda queda destrozada tras el golpe militar de Turquía en 1980.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZDE3MTBkNmQtNGFjMC00YTcwLWExY2ItN2MyMGZkNWJlMmFmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.2,
#      'ratingCount': 97457},
#     'contentRating': 'Not Rated',
#     'genre': 'Drama, Familiar',
#     'duration': 'PT1H52M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0074958/',
#     'name': 'Network',
#     'alternateName': 'Network, un mundo implacable',
#     'description': 'Una cadena de televisión explota cínicamente los desvaríos y las revelaciones de un antiguo ¿miembro? sobre los medios de comunicación para su propio beneficio.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZjI4ZjU5NDktZTU5YS00ZmQxLWI5YWYtMTJhY2ViMTcwMmJkXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 179349},
#     'contentRating': '18',
#     'genre': 'Drama',
#     'duration': 'PT2H1M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0129167/',
#     'name': 'The Iron Giant',
#     'alternateName': 'El gigante de hierro',
#     'description': 'Un joven se hace amigo de un robot gigante del espacio exterior, que un paranoico agente del Gobierno quiere destruir.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYzVmNmZmM2EtMWJiZi00ZmFiLTljMjEtYjk3OWYyZWZhNmI0XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 245008},
#     'contentRating': 'A',
#     'genre': 'Animación, Acción, Aventura',
#     'duration': 'PT1H26M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt4016934/',
#     'name': 'Ah-ga-ssi',
#     'alternateName': 'La doncella',
#     'description': 'Una mujer es contratada como criada de una heredera japonesa, pero está involucrada en un complot secreto para estafarla.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNTE4MTFkMWYtZDE4ZC00NDg2LTg5MzYtMTU2ZWExMGIyMWQ5XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 188523},
#     'contentRating': '16',
#     'genre': 'Drama, Romance, Suspense',
#     'duration': 'PT2H25M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt5323662/',
#     'name': 'Koe no katachi',
#     'alternateName': 'A Silent Voice',
#     'description': 'Un joven es condenado al ostracismo por sus compañeros de clase tras intimidar a una chica sorda hasta el punto de hacerla cambiar de escuela. Años más tarde, emprende el camino hacia la redención.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNTY4ZWIxNTctYmFlOC00YjI5LThjN2ItZDllMzIxYjQ3Y2ViXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 120962},
#     'contentRating': '16',
#     'genre': 'Animación, Drama',
#     'duration': 'PT2H10M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0035446/',
#     'name': 'To Be or Not to Be',
#     'alternateName': 'Ser o no ser',
#     'description': 'Durante la ocupación nazi de Polonia, un grupo de actores se ve envuelto en las actividades de un soldado polaco que intenta encontrar a un espía alemán.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjM0ZGQ0YTYtOTc4Ny00ZDc2LWE2NTUtMTJiYmVlZWIxOTY3XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 47092},
#     'contentRating': '14',
#     'genre': 'Comedia, Romance, Bélico',
#     'duration': 'PT1H39M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0058946/',
#     'name': 'La battaglia di Algeri',
#     'alternateName': 'La batalla de Argel',
#     'description': 'En la década de los 50, el miedo y la violencia aumentan a medida que la gente de Algiers lucha por la independencia del gobierno francés.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYTEyYWEzZmMtYTMyNi00NDI0LWIzZTAtOTE1NDIzOTQxNjJiXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 71135},
#     'contentRating': '18',
#     'genre': 'Drama, Bélico',
#     'duration': 'PT2H1M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0032551/',
#     'name': 'The Grapes of Wrath',
#     'alternateName': 'Las uvas de la ira',
#     'description': 'Una familia pobre del Medio Oeste se ve obligada a abandonar sus tierras. Viajan a California, sufriendo las desgracias de los sin techo en la Gran Depresión.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjc4N2RjNWYtYTA2YS00NzA3LWJhNmEtNTJmYmY4ZmJlMzQ1XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 104877},
#     'contentRating': 'A',
#     'genre': 'Drama',
#     'duration': 'PT2H9M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0758758/',
#     'name': 'Into the Wild',
#     'alternateName': 'Hacia rutas salvajes',
#     'description': 'Tras graduarse en la Universidad de Emory, el estudiante y atleta de élite Christopher McCandless abandona sus posesiones, dona a la caridad la totalidad de sus ahorros y viaja en autostop a Alaska para vivir en la naturaleza.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYmVmYmVmNzMtZTk3YS00ZjRlLTk0ZmItNGNlMjZkZWUxN2QxXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8,
#      'ratingCount': 679580},
#     'contentRating': '7',
#     'genre': 'Aventura, Biografía, Drama',
#     'duration': 'PT2H28M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0107048/',
#     'name': 'Groundhog Day',
#     'alternateName': 'Atrapado en el tiempo',
#     'description': 'Un hombre del tiempo revive inexplicablemente el mismo día una y otra vez.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjJiY2NhMTAtNDcyMS00NjU1LWE1ODAtYzc5MTE3MTE5ZTFkXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8,
#      'ratingCount': 716816},
#     'contentRating': 'T',
#     'genre': 'Comedia, Drama, Fantasía',
#     'duration': 'PT1H41M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt1454029/',
#     'name': 'The Help',
#     'alternateName': 'Criadas y señoras (The Help)',
#     'description': 'Un aspirante a autor durante el movimiento por los derechos civiles en los 60 decide escribir un libro des de la perspectiva de las asistentas domésticas afro-americanas sobre las familias blancas para las que trabajan.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYjQ0ZDQyNTItNDZmZS00ZmVlLTk4NzktOGM2NGQ1NzM4MjVkXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 513213},
#     'contentRating': 'A',
#     'genre': 'Drama',
#     'duration': 'PT2H26M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0245712/',
#     'name': 'Amores perros',
#     'description': 'Un horrible accidente automovilístico conecta tres historias, cada una de ellas con personajes que se enfrentan a la pérdida, el arrepentimiento y las duras realidades de la vida, todo ello en nombre del amor.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMmUzNDI1MDYtNmIxNC00NjczLTk0ZDEtYWFkZDcxMWVhYTEwXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8,
#      'ratingCount': 267914},
#     'contentRating': '18',
#     'genre': 'Drama, Suspense',
#     'duration': 'PT2H34M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt4430212/',
#     'name': 'Drishyam',
#     'description': 'Un hombre toma medidas desesperadas que intentan salvar a su familia del lado oscuro de la ley, luego de que cometen un crimen inesperado.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BM2NmMGFjYTYtNWEwNS00MTM4LWE2ZTktNzZjMTE0OTQyNjFiXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.2,
#      'ratingCount': 101275},
#     'contentRating': 'Not Rated',
#     'genre': 'Crimen, Drama, Misterio',
#     'duration': 'PT2H43M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0032976/',
#     'name': 'Rebecca',
#     'alternateName': 'Rebeca',
#     'description': 'Una mujer acomplejada hace esfuerzos para adaptarse a su nuevo papel como esposa de un aristócrata y evitar ser intimidada por la presencia fantasmal de su primera esposa.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjdlM2Y0ZDQtZmIzMi00NDVhLTk2M2ItMTRiZTRkOGIwNjA2XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 159247},
#     'contentRating': '14',
#     'genre': 'Drama, Misterio, Romance',
#     'duration': 'PT2H10M'}}],
#  '@context': 'https://schema.org',
#  'name': 'Las 250 mejores películas de IMDb',
#  'description': 'Según la calificación de los votantes habituales de IMDb.',
#  'url': 'https://www.imdb.com/es-es/chart/top/'}

# %%
soup.find_all("img", alt=True)[1]
# Out:
# <img alt="Morgan Freeman and Tim Robbins in Cadena perpetua (1994)" class="ipc-image" loading="lazy" sizes="50vw, (min-width: 480px) 34vw, (min-width: 600px) 26vw, (min-width: 1024px) 16vw, (min-width: 1280px) 16vw" src="https://m.media-amazon.com/images/M/MV5BMTA1MjE0Nzk4MDleQTJeQWpwZ15BbWU4MDA0NjIxMjAx._V1_QL75_UY207_CR6,0,140,207_.jpg" srcset="https://m.media-amazon.com/images/M/MV5BMTA1MjE0Nzk4MDleQTJeQWpwZ15BbWU4MDA0NjIxMjAx._V1_QL75_UY207_CR6,0,140,207_.jpg 140w, https://m.media-amazon.com/images/M/MV5BMTA1MjE0Nzk4MDleQTJeQWpwZ15BbWU4MDA0NjIxMjAx._V1_QL75_UY311_CR8,0,210,311_.jpg 210w, https://m.media-amazon.com/images/M/MV5BMTA1MjE0Nzk4MDleQTJeQWpwZ15BbWU4MDA0NjIxMjAx._V1_QL75_UY414_CR11,0,280,414_.jpg 280w" width="140"/>

# %%
import re
# re.search(r"\((\d{4})\)",soup.find_all("img", alt=True)[1]['alt']).group().strip("()")

# %%
img_tags = soup.find_all("img", alt=True)
img_tags

# %%
peliculas = {"titulo":[], "anio": [], "duracion": [], "posicion": [], "rating":[]}

# %%
for i, entry in enumerate(movies_json["itemListElement"], start=1):
    movie = entry["item"]
    
    title = movie.get("alternateName") or movie.get("name")
    rating = movie.get("aggregateRating", {}).get("ratingValue", "N/A")
    duration = movie.get("duration", "N/A")
    url = movie.get("url", "N/A")

    # if 'alt' in img_tags[i]:
    #     match = re.search(r"\((\d{4})\)",img_tags[i]['alt']) 

    #     if match:
    #         year = match.group().strip("()")

    # que no vale esta versión dado que solo 28 pelis tienen alt ... mi gozo en un pozo
    

    peliculas['titulo'].append(title)
    peliculas['anio'].append(year)
    peliculas['duracion'].append(duration)
    peliculas['posicion'].append(i)
    peliculas['rating'].append(rating)

# %%
peliculas

# %%
df = pd.DataFrame(peliculas)
df.to_csv("peliculas_imdb_anio_rgx.csv")

# %%
df

# %%
# alternativa

soup.find_all('h3', class_ = "ipc-title__text")[1:-1]       # solo genera 25 lazy loading
# Out:
# [<h3 class="ipc-title__text ipc-title__text--reduced">1. Cadena perpetua</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">2. El padrino</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">3. El caballero oscuro</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">4. El padrino parte II</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">5. 12 hombres sin piedad</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">6. El señor de los anillos: El retorno del rey</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">7. La lista de Schindler</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">8. Pulp Fiction</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">9. El señor de los anillos: La comunidad del anillo</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">10. El bueno, el feo y el malo</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">11. Forrest Gump</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">12. El señor de los anillos: Las dos torres</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">13. El club de la lucha</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">14. Origen</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">15. El imperio contraataca</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">16. Matrix</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">17. Uno de los nuestros</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">18. Interstellar</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">19. Alguien voló sobre el nido del cuco</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">20. Seven</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">21. Qué bello es vivir</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">22. El silencio de los corderos</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">23. Los siete samuráis</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">24. Salvar al soldado Ryan</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">25. Ciudad de Dios</h3>]

# %%
list_rnk = []
list_anio = []
list_duracion = []
list_edad = []
list_nombre = []

for x in soup.find_all('h3', class_ = "ipc-title__text")[1:-1]:
    list_rnk.append(x.get_text().split('. ')[0])
    list_nombre. append(x.get_text().split('. ')[1])

# %%
soup.find_all("div", class_="sc-4b408797-7 fUdAcX cli-title-metadata")
# Out:
# [<div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1994</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2h 22m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">13</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1972</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2h 55m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">18</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2008</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2h 32m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">13</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1974</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">3h 22m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">18</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1957</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1h 36m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">A</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2003</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">3h 21m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">13</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1993</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">3h 15m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">13</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1994</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2h 34m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">18</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2001</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2h 58m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">12</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1966</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">3h 2m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">14</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1994</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2h 22m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">A</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2002</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2h 59m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">13</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1999</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2h 19m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">18</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2010</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2h 28m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">12</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1980</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2h 4m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">A</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1999</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2h 16m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">18</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1990</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2h 25m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">18</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2014</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2h 49m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">12</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1975</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2h 13m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">18</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1995</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2h 7m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">18</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1946</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2h 10m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">A</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1991</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1h 58m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">18</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1954</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">3h 27m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">A</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">1998</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2h 49m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">13</span></div>,
#  <div class="sc-4b408797-7 fUdAcX cli-title-metadata"><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2002</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">2h 10m</span><span class="sc-4b408797-8 iurwGb cli-title-metadata-item">18</span></div>]

# %%
for y in soup.find_all("span", class_="sc-4b408797-8 iurwGb cli-title-metadata-item"):
    # print(y.get_text())

    if len(y.text) == 4: 
        list_anio.append(y.text)
    if len(y.text) > 4:
        list_duracion.append(y.text)
    if len(y.text) > 0 and len(y.text) <= 2:
        list_edad.append(y.text)

# %%
print(list_anio)
print(list_duracion)
print(list_edad)
# Out:
# ['1994', '1972', '2008', '1974', '1957', '2003', '1993', '1994', '2001', '1966', '1994', '2002', '1999', '2010', '1980', '1999', '1990', '2014', '1975', '1995', '1946', '1991', '1954', '1998', '2002']
# ['2h 22m', '2h 55m', '2h 32m', '3h 22m', '1h 36m', '3h 21m', '3h 15m', '2h 34m', '2h 58m', '3h 2m', '2h 22m', '2h 59m', '2h 19m', '2h 28m', '2h 4m', '2h 16m', '2h 25m', '2h 49m', '2h 13m', '2h 7m', '2h 10m', '1h 58m', '3h 27m', '2h 49m', '2h 10m']
# ['13', '18', '13', '18', 'A', '13', '13', '18', '12', '14', 'A', '13', '18', '12', 'A', '18', '18', '12', '18', '18', 'A', '18', 'A', '13', '18']

# %%
list_rating = []
for z in soup.find_all("span", class_ = 'ipc-rating-star--rating'):
    list_rating.append(z.text)

# %%
df = pd.DataFrame({
    "Ranking":list_rnk,
    "Titulo":list_nombre,
    "Anio": list_anio,
    "Duracion": list_duracion,
    "Edad": list_edad,
    "Rating": list_rating
})

# %%
df.to_csv('alt_movies.csv', index=False)

# %%
df
# Out:
#    Ranking                                            Titulo  Anio Duracion  \
# 0        1                                   Cadena perpetua  1994   2h 22m
# 1        2                                        El padrino  1972   2h 55m
# 2        3                               El caballero oscuro  2008   2h 32m
# 3        4                               El padrino parte II  1974   3h 22m
# 4        5                             12 hombres sin piedad  1957   1h 36m
# 5        6       El señor de los anillos: El retorno del rey  2003   3h 21m
# 6        7                             La lista de Schindler  1993   3h 15m
# 7        8                                      Pulp Fiction  1994   2h 34m
# 8        9  El señor de los anillos: La comunidad del anillo  2001   2h 58m
# 9       10                        El bueno, el feo y el malo  1966    3h 2m
# 10      11                                      Forrest Gump  1994   2h 22m
# 11      12           El señor de los anillos: Las dos torres  2002   2h 59m
# 12      13                               El club de la lucha  1999   2h 19m
# 13      14                                            Origen  2010   2h 28m
# 14      15                            El imperio contraataca  1980    2h 4m
# 15      16                                            Matrix  1999   2h 16m
# 16      17                               Uno de los nuestros  1990   2h 25m
# 17      18                                      Interstellar  2014   2h 49m
# 18      19               Alguien voló sobre el nido del cuco  1975   2h 13m
# 19      20                                             Seven  1995    2h 7m
# 20      21                                Qué bello es vivir  1946   2h 10m
# 21      22                       El silencio de los corderos  1991   1h 58m
# 22      23                                Los siete samuráis  1954   3h 27m
# 23      24                            Salvar al soldado Ryan  1998   2h 49m
# 24      25                                    Ciudad de Dios  2002   2h 10m
#
#    Edad Rating
# 0    13    9,3
# 1    18    9,2
# 2    13    9,0
# 3    18    9,0
# 4     A    9,0
# 5    13    9,0
# 6    13    9,0
# 7    18    8,9
# 8    12    8,9
# 9    14    8,8
# 10    A    8,8
# 11   13    8,8
# 12   18    8,8
# 13   12    8,8
# 14    A    8,7
# 15   18    8,7
# 16   18    8,7
# 17   12    8,7
# 18   18    8,7
# 19   18    8,6
# 20    A    8,6
# 21   18    8,6
# 22    A    8,6
# 23   13    8,6
# 24   18    8,6

# %% [markdown]
# ## JSON

# %%
import json

# %%
soup.find_all("script", type="application/ld+json")
# Out:
# [<script type="application/ld+json">{"@type":"ItemList","itemListElement":[{"@type":"ListItem","item":{"@type":"Movie","url":"https://www.imdb.com/es-es/title/tt0111161/","name":"The Shawshank Redemption","alternateName":"Cadena perpetua","description":"Andy Dufresne es encarcelado por matar a su esposa y al amante de esta. Tras una dura adaptación, intenta mejorar las condiciones de la prisión y dar esperanza a sus compañeros.","image":"https://m.media-amazon.com/images/M/MV5BMTA1MjE0Nzk4MDleQTJeQWpwZ15BbWU4MDA0NjIxMjAx._V1_.jpg","aggregateRating":{"@type":"AggregateRating","bestRating":10,"worstRating":1,"ratingValue":9.3,"ratingCount":3045590},"contentRating":"13","genre":"Drama","duration":"PT2H22M"}},{"@type":"ListItem","item":{"@type":"Movie","url":"https://www.imdb.com/es-es/title/tt0068646/","name":"The Godfather","alternateName":"El padrino","description":"El envejecido patriarca de una dinastía del crimen organizado en la ciudad de Nueva York de la posguerra transfiere el control de su imperio clandestino a su reacio hijo menor.","image":"https://m.media-amazon.com/images/M/MV5BNTljNjllNDAtMzc0MS00ZGExLThlOTktOTRlNzc3YjA3ZWFlXkEyXkFqcGc@._V1_.jpg","aggregateRating":{"@type":"AggregateRating","bestRating":10,"worstRating":1,"ratingValue":9.2,"ratingCount":2126064},"contentRating":"18","genre":"Crimen, Drama","duration":"PT2H55M"}},{"@type":"ListItem","item":{"@type":"Movie","url":"https://www.imdb.com/es-es/title/tt0468569/","name":"The Dark Knight","alternateName":"El caballero oscuro","description":"Cuando la amenaza conocida como el Joker causa estragos y el caos en Gotham City, Batman debe aceptar una de las mayores pruebas psicológicas y físicas para luchar contra la injusticia.","image":"https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_.jpg","aggregateRating":{"@type":"AggregateRating","bestRating":10,"worstRating":1,"ratingValue":9,"ratingCount":3022443},"contentRating":"13","genre":"Acción, Crimen, Drama","duration":"PT2H32M"}},{"@type":"ListItem","item":{"@type":"Movie","url":"https://www.imdb.com/es-es/title/tt0071562/","name":"The Godfather Part II","alternateName":"El padrino parte II","description":"Se retratan los inicios de la vida y la carrera de Vito Corleone en el Nueva York de los años 20, mientras su hijo, Michael, amplía y refuerza su control sobre el sindicato del crimen familiar.","image":"https://m.media-amazon.com/images/M/MV5BMjQ5MzQxZTEtMmE1Yy00NjZlLTk5ODItNjI3MWIxMjk1M2U5XkEyXkFqcGc@._V1_.jpg","aggregateRating":{"@type":"AggregateRating","bestRating":10,"worstRating":1,"ratingValue":9,"ratingCount":1430228},"contentRating":"18","genre":"Crimen, Drama","duration":"PT3H22M"}},{"@type":"ListItem","item":{"@type":"Movie","url":"https://www.imdb.com/es-es/title/tt0050083/","name":"12 Angry Men","alternateName":"12 hombres sin piedad","description":"Un miembro del jurado trata de evitar un error judicial obligando al resto del jurado a reconsiderar las pruebas.","image":"https://m.media-amazon.com/images/M/MV5BYThhOGFhODktNGEwNi00MzY2LTg3YWYtNzAzZTE0MTFlMWQxXkEyXkFqcGc@._V1_.jpg","aggregateRating":{"@type":"AggregateRating","bestRating":10,"worstRating":1,"ratingValue":9,"ratingCount":925964},"contentRating":"A","genre":"Crimen, Drama","duration":"PT1H36M"}},{"@type":"ListItem","item":{"@type":"Movie","url":"https://www.imdb.com/es-es/title/tt0167260/","name":"The Lord of the Rings: The Return of the King","alternateName":"El señor de los anillos: El retorno del rey","description":"Gandalf y Aragorn lideran el mundo de los hombres contra la armada de Sauron para distraer su atención de Frodo y Sam, quienes se aproximan al Monte del Destino con el Anillo Único.","image":"https://m.media-amazon.com/images/M/MV5BZGEzZDkzNDgtMGMzZi00NjNhLTliNWMtMTllYzQ2OTQwNGFkXkEyXkFqcGc@._V1_.jpg","aggregateRating":{"@type":"AggregateRating","bestRating":10,"worstRating":1,"ratingValue":9,"ratingCount":2078873},"contentRating":"13","genre":"Aventura, Drama, Fantasía","duratio ...

# %%
data = json.loads(soup.find("script", type="application/ld+json").text) # para coger solo el contenido
data
# Out:
# {'@type': 'ItemList',
#  'itemListElement': [{'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0111161/',
#     'name': 'The Shawshank Redemption',
#     'alternateName': 'Cadena perpetua',
#     'description': 'Andy Dufresne es encarcelado por matar a su esposa y al amante de esta. Tras una dura adaptación, intenta mejorar las condiciones de la prisión y dar esperanza a sus compañeros.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMTA1MjE0Nzk4MDleQTJeQWpwZ15BbWU4MDA0NjIxMjAx._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 9.3,
#      'ratingCount': 3045590},
#     'contentRating': '13',
#     'genre': 'Drama',
#     'duration': 'PT2H22M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0068646/',
#     'name': 'The Godfather',
#     'alternateName': 'El padrino',
#     'description': 'El envejecido patriarca de una dinastía del crimen organizado en la ciudad de Nueva York de la posguerra transfiere el control de su imperio clandestino a su reacio hijo menor.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNTljNjllNDAtMzc0MS00ZGExLThlOTktOTRlNzc3YjA3ZWFlXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 9.2,
#      'ratingCount': 2126064},
#     'contentRating': '18',
#     'genre': 'Crimen, Drama',
#     'duration': 'PT2H55M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0468569/',
#     'name': 'The Dark Knight',
#     'alternateName': 'El caballero oscuro',
#     'description': 'Cuando la amenaza conocida como el Joker causa estragos y el caos en Gotham City, Batman debe aceptar una de las mayores pruebas psicológicas y físicas para luchar contra la injusticia.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 9,
#      'ratingCount': 3022443},
#     'contentRating': '13',
#     'genre': 'Acción, Crimen, Drama',
#     'duration': 'PT2H32M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0071562/',
#     'name': 'The Godfather Part II',
#     'alternateName': 'El padrino parte II',
#     'description': 'Se retratan los inicios de la vida y la carrera de Vito Corleone en el Nueva York de los años 20, mientras su hijo, Michael, amplía y refuerza su control sobre el sindicato del crimen familiar.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjQ5MzQxZTEtMmE1Yy00NjZlLTk5ODItNjI3MWIxMjk1M2U5XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 9,
#      'ratingCount': 1430228},
#     'contentRating': '18',
#     'genre': 'Crimen, Drama',
#     'duration': 'PT3H22M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0050083/',
#     'name': '12 Angry Men',
#     'alternateName': '12 hombres sin piedad',
#     'description': 'Un miembro del jurado trata de evitar un error judicial obligando al resto del jurado a reconsiderar las pruebas.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYThhOGFhODktNGEwNi00MzY2LTg3YWYtNzAzZTE0MTFlMWQxXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 9,
#      'ratingCount': 925964},
#     'contentRating': 'A',
#     'genre': 'Crimen, Drama',
#     'duration': 'PT1H36M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0167260/',
#     'name': 'The Lord of the Rings: The Return of the King',
#     'alternateName': 'El señor de los anillos: El retorno del rey',
#     'description': 'Gandalf y Aragorn lideran el mundo de los hombres contra la armada de Sauron para distraer su atención de Frodo y Sam, quienes se aproximan al Monte del Destino con el Anillo Único.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZGEzZDkzNDgtMGMzZi00NjNhLTliNWMtMTllYzQ2OTQwNGFkXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 9,
#      'ratingCount': 2078873},
#     'contentRating': '13',
#     'genre': 'Aventura, Drama, Fantasía',
#     'duration': 'PT3H21M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0108052/',
#     'name': 'Schindler&apos;s List',
#     'alternateName': 'La lista de Schindler',
#     'description': 'En la Polonia ocupada por los alemanes durante la Segunda Guerra Mundial, el industrial Oskar Schindler se preocupa por sus trabajadores judíos tras presenciar su persecución por los nazis.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZWUyNTJmOTMtZGM4MC00NWE2LThmZTUtZWE1NGM2YzYwZjRlXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 9,
#      'ratingCount': 1523386},
#     'contentRating': '13',
#     'genre': 'Biografía, Drama, Historia',
#     'duration': 'PT3H15M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0110912/',
#     'name': 'Pulp Fiction',
#     'description': 'Las vidas de dos mafiosos, un boxeador, la esposa de un gánster y un par de bandidos se entrelazan en cuatro historias de violencia y redención.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMzNlNGRkZWYtNmE0Yy00NjQyLWFmMzItYWY5NGM2YWU4OWYwXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.9,
#      'ratingCount': 2335919},
#     'contentRating': '18',
#     'genre': 'Crimen, Drama',
#     'duration': 'PT2H34M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0120737/',
#     'name': 'The Lord of the Rings: The Fellowship of the Ring',
#     'alternateName': 'El señor de los anillos: La comunidad del anillo',
#     'description': 'Un hobbit de la Comarca y ocho compañeros emprenden un viaje para destruir el poderoso Anillo Único y salvar la Tierra Media del Señor Oscuro Sauron.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNDM0ZTRjNDAtMWFiOS00MjZiLThhZjYtNGQ0ODQ5MGE3Y2Y0XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.9,
#      'ratingCount': 2108885},
#     'contentRating': '12',
#     'genre': 'Aventura, Drama, Fantasía',
#     'duration': 'PT2H58M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0060196/',
#     'name': 'Il buono, il brutto, il cattivo',
#     'alternateName': 'El bueno, el feo y el malo',
#     'description': 'Durante la guerra de Secesión, tres cazarrecompensas se lanzan a la búsqueda de un tesoro que ninguno puede localizar sin la ayuda de los otros dos.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BN2FmNmM5OTUtODEwMC00NDE5LWI4ZTUtZTg1ZmZlYjVjN2EyXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.8,
#      'ratingCount': 853718},
#     'contentRating': '14',
#     'genre': 'Aventura, Del oeste',
#     'duration': 'PT3H2M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0109830/',
#     'name': 'Forrest Gump',
#     'description': 'Las presidencias de Kennedy y Johnson, los acontecimientos de Vietnam, el Watergate y otros eventos históricos se desarrollan a través de la perspectiva de un hombre de Alabama con un coeficiente intelectual de 75.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BOWQ0NzQ5MDItYTA3Yy00Y2ZjLWFlMGQtNjcxYzU4MWM3NzFmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.8,
#      'ratingCount': 2380426},
#     'contentRating': 'A',
#     'genre': 'Drama, Romance',
#     'duration': 'PT2H22M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0167261/',
#     'name': 'The Lord of the Rings: The Two Towers',
#     'alternateName': 'El señor de los anillos: Las dos torres',
#     'description': 'Mientras Frodo y Sam se acercan a Mordor con la ayuda del astuto Gollum, la comunidad dividida se enfrenta al nuevo aliado de Sauron, Saruman, y a sus hordas de Isengard.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNjJhZjZlNjktZTEwYi00MmMwLTgyYTgtYmMyMmRlOWMzNmRjXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.8,
#      'ratingCount': 1874455},
#     'contentRating': '13',
#     'genre': 'Aventura, Drama, Fantasía',
#     'duration': 'PT2H59M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0137523/',
#     'name': 'Fight Club',
#     'alternateName': 'El club de la lucha',
#     'description': 'Un oficinista insomne y un fabricante de jabones forman un club de lucha clandestino que se convierte en mucho más.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZjA1YzQ3MDktYzRjMi00NWQ0LWFhYWYtZGMyODcwNGEwZjNmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.8,
#      'ratingCount': 2466667},
#     'contentRating': '18',
#     'genre': 'Crimen, Drama, Suspense',
#     'duration': 'PT2H19M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt1375666/',
#     'name': 'Inception',
#     'alternateName': 'Origen',
#     'description': 'A un ladrón que roba secretos corporativos a través del uso de la tecnología de compartir sueños, se le da la tarea de implantar una idea en la mente de un jefe de una gran empresa.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNTQxYmM1NzQtY2FiZS00MzRhLTljZDYtZjRmMGNiMWI3NTQxXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.8,
#      'ratingCount': 2684780},
#     'contentRating': '12',
#     'genre': 'Acción, Aventura, Ciencia ficción',
#     'duration': 'PT2H28M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0080684/',
#     'name': 'Star Wars: Episode V - The Empire Strikes Back',
#     'alternateName': 'El imperio contraataca',
#     'description': 'Tras ser brutalmente dominados los rebeldes por el Imperio en el planeta helado Hoth, Luke Skywalker comienza su entrenamiento jedi con Yoda, mientras sus amigos son perseguidos por Darth Vader y el cazarrecompensas Boba Fett.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZWQyNTJkMTAtZWQ0Zi00NGFlLWI2ZDktNTA4MzM5NDQ0MTk4XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.7,
#      'ratingCount': 1442625},
#     'contentRating': 'A',
#     'genre': 'Acción, Aventura, Fantasía',
#     'duration': 'PT2H4M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0133093/',
#     'name': 'The Matrix',
#     'alternateName': 'Matrix',
#     'description': 'Cuando una bella desconocida lleva al hacker Neo a un inframundo prohibido, descubre la impactante verdad: la vida que conoce es un elaborado engaño de una ciberinteligencia malvada.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNGE1YzI4NzMtZTUxNi00Y2I5LTg2MmQtODE0NThmYTFmMDk0XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.7,
#      'ratingCount': 2156806},
#     'contentRating': '18',
#     'genre': 'Acción, Ciencia ficción',
#     'duration': 'PT2H16M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0099685/',
#     'name': 'GoodFellas',
#     'alternateName': 'Uno de los nuestros',
#     'description': 'La historia de Henry Hill y su vida en la mafia, abarcando su relación con su esposa Karen Hill y sus socios mafiosos Jimmy Conway y Tommy DeVito en el sindicato del crimen italoamericano.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYTE0MmJhNGUtZDI5My00YThhLTk1NmItNDExOWUxMjg1YzUxXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.7,
#      'ratingCount': 1326790},
#     'contentRating': '18',
#     'genre': 'Biografía, Crimen, Drama',
#     'duration': 'PT2H25M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0816692/',
#     'name': 'Interstellar',
#     'description': 'Un equipo de exploradores viaja a través de un agujero de gusano en el espacio en un intento de garantizar la supervivencia de la humanidad.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYzdjMDAxZGItMjI2My00ODA1LTlkNzItOWFjMDU5ZDJlYWY3XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.7,
#      'ratingCount': 2346977},
#     'contentRating': '12',
#     'genre': 'Aventura, Drama, Ciencia ficción',
#     'duration': 'PT2H49M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0073486/',
#     'name': 'One Flew Over the Cuckoo&apos;s Nest',
#     'alternateName': 'Alguien voló sobre el nido del cuco',
#     'description': 'Un criminal alega locura para ser enviado a un centro de salud mental, donde se rebela contra la opresiva enfermera y moviliza a los pacientes, a quienes tienen atemorizados.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYjdkNjdlNDgtZTM1My00YzEwLTk5YjItYjE3YzllZTViNTVlXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.7,
#      'ratingCount': 1117157},
#     'contentRating': '18',
#     'genre': 'Drama',
#     'duration': 'PT2H13M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0114369/',
#     'name': 'Se7en',
#     'alternateName': 'Seven',
#     'description': 'Dos detectives, un novato y un veterano, dan caza a un asesino en serie cuyo móvil son los siete pecados capitales.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjk4YWQ5YTItZTk2OS00MTcxLWIwNjctZjE3NzNhNjQzZjI2XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 1912593},
#     'contentRating': '18',
#     'genre': 'Crimen, Drama, Misterio',
#     'duration': 'PT2H7M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0038650/',
#     'name': 'It&apos;s a Wonderful Life',
#     'alternateName': 'Qué bello es vivir',
#     'description': 'Un ángel es enviado desde el cielo para ayudar a un hombre de negocios desesperadamente frustrado, mostrándole cómo habría sido la vida si él nunca hubiera existido.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BOWIzZDkwM2MtMWU5Yy00NzA5LWFhMzUtMmI1Yzc4NWQzMzg2XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 527946},
#     'contentRating': 'A',
#     'genre': 'Drama, Familiar, Fantasía',
#     'duration': 'PT2H10M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0102926/',
#     'name': 'The Silence of the Lambs',
#     'alternateName': 'El silencio de los corderos',
#     'description': 'Una joven cadete del FBI busca la ayuda de un asesino caníbal y manipulador encarcelado con el fin de atrapar a otro asesino en serie, un loco que despelleja a sus víctimas.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BOGZiZjYxY2UtNDE5YS00NzcwLWI0NmItNjcwYThkOWMwYTdhXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 1636422},
#     'contentRating': '18',
#     'genre': 'Crimen, Drama, Terror',
#     'duration': 'PT1H58M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0047478/',
#     'name': 'Shichinin no samurai',
#     'alternateName': 'Los siete samuráis',
#     'description': 'Un pueblo pobre atacado por bandidos recluta a siete samuráis desempleados para que les ayuden a defenderse.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYzc0ODMyMzctZTA5Zi00MGZhLWE0NTItZjJhOTE3OWMxZjBlXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 384270},
#     'contentRating': 'A',
#     'genre': 'Acción, Drama',
#     'duration': 'PT3H27M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0120815/',
#     'name': 'Saving Private Ryan',
#     'alternateName': 'Salvar al soldado Ryan',
#     'description': 'Tras el desembarco de Normandía, un grupo de soldados estadounidenses cruza las líneas enemigas para rescatar a un paracaidista cuyos hermanos han muerto en combate.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMzU0YTgzM2EtYWNmMy00NWM1LWE0NTMtYjFhZDNlMDU1NWJmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 1570738},
#     'contentRating': '13',
#     'genre': 'Drama, Bélico',
#     'duration': 'PT2H49M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0317248/',
#     'name': 'Cidade de Deus',
#     'alternateName': 'Ciudad de Dios',
#     'description': 'En un barrio pobre de Rio, los caminos de dos niños se cruzan mientras uno quiere ser fotógrafo y el otro capo.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYjY4NGI5OTUtY2ZlZS00Zjk4LTk5N2MtN2JmYWVjNGNmMGRlXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 837826},
#     'contentRating': '18',
#     'genre': 'Crimen, Drama',
#     'duration': 'PT2H10M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0120689/',
#     'name': 'The Green Mile',
#     'alternateName': 'La milla verde',
#     'description': 'Las vidas de los guardias del corredor de la muerte se ven afectadas por uno de sus reclusos: un hombre negro acusado de asesinato y violación de niños, pero que tiene un misterioso don.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BM2VlMDA2NWYtYzQxZi00NGIyLTk0OTYtMGY3ODFmOGFhMTI3XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 1486550},
#     'contentRating': '13',
#     'genre': 'Crimen, Drama, Fantasía',
#     'duration': 'PT3H9M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0118799/',
#     'name': 'La vita è bella',
#     'alternateName': 'La vida es bella',
#     'description': 'Cuando un bibliotecario judío y su hijo se convierten en víctimas del Holocausto, él usará una perfecta mezcla de voluntad, humor e imaginación para proteger a su hijo de los peligros en el campo de concentración.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNTZhN2IwZWUtNTI2Yy00OWNjLWExZmYtOGMzN2M5NTE1MzM1XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 778723},
#     'contentRating': 'A',
#     'genre': 'Comedia, Drama, Romance',
#     'duration': 'PT1H56M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0103064/',
#     'name': 'Terminator 2: Judgment Day',
#     'alternateName': 'Terminator 2: El juicio final',
#     'description': 'Un cyborg, idéntico al que fracasó en su intento de matar a Sarah Connor, debe proteger ahora a su hijo adolescente John de un cyborg más avanzado y poderoso.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BM2U1MTc3M2EtYzhjYy00MmRkLWExZDEtZmI0OWNjMTFkODlmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 1233265},
#     'contentRating': '18',
#     'genre': 'Acción, Aventura, Ciencia ficción',
#     'duration': 'PT2H17M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0076759/',
#     'name': 'Star Wars',
#     'alternateName': 'La guerra de las galaxias',
#     'description': 'Luke Skywalker une sus fuerzas con un caballero jedi, un piloto fanfarrón, un wookiee y dos droides para salvar a la galaxia de la estación espacial del Imperio, a la vez que intenta rescatar a la princesa Leia del malvado Darth V...',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNGU3YTdiM2EtY2Y3MC00NTIzLWEzYzYtM2IxZDNhZjkwNjU1XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 1509804},
#     'contentRating': 'A',
#     'genre': 'Acción, Aventura, Fantasía',
#     'duration': 'PT2H1M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0088763/',
#     'name': 'Back to the Future',
#     'alternateName': 'Regreso al futuro',
#     'description': 'Marty McFly, un estudiante de secundaria de 17 años, es enviado accidentalmente treinta años al pasado en un DeLorean que viaja en el tiempo, inventado por su gran amigo, el excéntrico científico Doc Brown.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNzVhMDRlMzctMjgxOC00MDllLTkzZWUtZTk4ODgyNDgwZTBmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1378558},
#     'contentRating': 'A',
#     'genre': 'Aventura, Comedia, Ciencia ficción',
#     'duration': 'PT1H56M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0245429/',
#     'name': 'Sen to Chihiro no kamikakushi',
#     'alternateName': 'El viaje de Chihiro',
#     'description': 'Durante el traslado de su familia a los suburbios, una niña de 10 años de edad deambula por un mundo gobernado por dioses, brujas y espíritus, y donde los humanos se convierten en bestias.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMWI1OTdjN2EtOGUxYy00ZDBmLWFlNzAtNmRkZjhiMTIzOTNhXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 911046},
#     'contentRating': 'A',
#     'genre': 'Animación, Aventura, Familiar',
#     'duration': 'PT2H4M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0253474/',
#     'name': 'The Pianist',
#     'alternateName': 'El pianista',
#     'description': 'Un músico judío polaco lucha por sobrevivir a la destrucción del gueto de Varsovia durante la Segunda Guerra Mundial.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjEwNmEwYjgtNTk3ZC00NjljLTg5ZDctZTY3ZGQwZjRkZmQxXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 968826},
#     'contentRating': '13',
#     'genre': 'Biografía, Drama, Música',
#     'duration': 'PT2H30M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0172495/',
#     'name': 'Gladiator',
#     'alternateName': 'Gladiator (El gladiador)',
#     'description': 'Un exgeneral romano se propone vengarse del emperador corrupto que asesinó a su familia y lo envió a la esclavitud.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZDZlZjY4NGMtNWIwNC00OWVhLTkyMmUtODI5ZDY4MmFhODllXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1760960},
#     'contentRating': '13',
#     'genre': 'Acción, Aventura, Drama',
#     'duration': 'PT2H35M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt6751668/',
#     'name': 'Gisaengchung',
#     'alternateName': 'Parásitos',
#     'description': 'La familia Ki-taek, todos desempleados, se ve envuelta en un incidente con la rica y glamurosa familia Parks.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYjk1Y2U4MjQtY2ZiNS00OWQyLWI3MmYtZWUwNmRjYWRiNWNhXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1063671},
#     'contentRating': '16',
#     'genre': 'Drama, Suspense',
#     'duration': 'PT2H12M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0054215/',
#     'name': 'Psycho',
#     'alternateName': 'Psicosis',
#     'description': 'Una secretaria de Phoenix malversa cuarenta mil dólares de un cliente, se da a la fuga y se registra en un motel remoto administrado por un joven con una controladora madre.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BOTUxZGRkZjQtMGFjOS00YTZkLTg5MmItOGRhMjE3YjQyMjBmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 752942},
#     'contentRating': '16',
#     'genre': 'Drama, Terror, Misterio',
#     'duration': 'PT1H49M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0110357/',
#     'name': 'The Lion King',
#     'alternateName': 'El rey león',
#     'description': 'El pequeño león Simba, príncipe heredero, es engañado por su malvado tío, quien desea el trono para sí mismo.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BOTk0YjM0YmMtZTNiOC00ZjU5LWEzNmUtNTRiYzAxMTg0MzVkXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1204140},
#     'contentRating': 'A',
#     'genre': 'Animación, Aventura, Drama',
#     'duration': 'PT1H28M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0095327/',
#     'name': 'Hotaru no haka',
#     'alternateName': 'La tumba de las luciérnagas',
#     'description': 'Un chico y su hermana pequeña intentan sobrevivir en Japón durante la Segunda Guerra Mundial.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BOTBlY2ViYmQtOWIzYy00NDRjLTg4ZDgtNWJiYWU1MjNlMDcwXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 349619},
#     'contentRating': '13',
#     'genre': 'Animación, Drama, Bélico',
#     'duration': 'PT1H28M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0407887/',
#     'name': 'The Departed',
#     'alternateName': 'Infiltrados',
#     'description': 'Un policía de incógnito y un topo en el departamento de policía intentan identificarse el uno al otro mientras se infiltran en una banda irlandesa en el sur de Boston.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYjhhMWVjMTUtM2EyMi00ZTU4LWIzNmYtZjMyNzJiMmZjMWRmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1488613},
#     'contentRating': '18',
#     'genre': 'Crimen, Drama, Suspense',
#     'duration': 'PT2H31M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt2582802/',
#     'name': 'Whiplash',
#     'description': 'Un joven y prometedor batería se inscribe en un competitivo conservatorio donde sus sueños de grandeza son guiados por un instructor que no se detiene ante nada para realizar el potencial de su estudiante.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjM0NmUzOWUtN2I0Mi00NTRiLWJmNzItZDE2YWIwNDIwNmEzXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1075047},
#     'contentRating': '12',
#     'genre': 'Drama, Música',
#     'duration': 'PT1H46M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0056058/',
#     'name': 'Seppuku',
#     'alternateName': 'Harakiri',
#     'description': 'Un viejo samurái ronin llega a la casa de un señor feudal y pide un lugar honorable donde poder suicidarse. Pero cuando el ronin pregunta por un samurái más joven que llegó antes que él, los acontecimientos toman un rumbo inesperado.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZThiZjU5ZDQtZDI4Mi00ZGYyLTkzOTktYmIzZTFlZTkxYzg5XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.6,
#      'ratingCount': 79737},
#     'contentRating': '13',
#     'genre': 'Drama, Misterio',
#     'duration': 'PT2H13M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0482571/',
#     'name': 'The Prestige',
#     'alternateName': 'El truco final (El prestigio)',
#     'description': 'Tras un trágico accidente, dos magos en el Londres de 1890 se enfrentan para crear la ilusión definitiva, mientras sacrifican todo lo que tienen para superar al otro.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjUxYzNmOWItZjc1NS00OTUxLTgzODEtODU2NGEzMDJmYWFjXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1515484},
#     'contentRating': '18',
#     'genre': 'Drama, Misterio, Ciencia ficción',
#     'duration': 'PT2H10M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0120586/',
#     'name': 'American History X',
#     'description': 'Un exmilitante de los skinheads neonazis intenta disuadir a su hermano pequeño de tomar las mismas malas decisiones que él tomó.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjU3OWQ2MWQtZTMzNS00MGRjLWE3MmQtZmQ1Mzc0MGY3NmQyXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1231577},
#     'contentRating': '13',
#     'genre': 'Crimen, Drama',
#     'duration': 'PT1H59M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0110413/',
#     'name': 'Léon',
#     'alternateName': 'El profesional (Léon)',
#     'description': 'Leon, un asesino a sueldo profesional, se hace cargo con recelo de Matilda, una niña de 12 años, cuando su familia es asesinada. Leon y Matilda entablan una inusual relación cuando ella se convierte en su protegida y aprende el of...',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNGRkYTNhOWQtYmI0Ni00MjZhLWJmMzAtMTA2Mjg4NGNiNDU0XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1303359},
#     'contentRating': '18',
#     'genre': 'Acción, Crimen, Drama',
#     'duration': 'PT1H50M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt9362722/',
#     'name': 'Spider-Man: Across the Spider-Verse',
#     'alternateName': 'Spider-Man: Cruzando el multiverso',
#     'description': 'Miles Morales conoce a un nuevo equipo de Spider-People formado por héroes de diferentes dimensiones. Pero cuando los héroes se enfrentan sobre cómo hacer frente a una nueva amenaza, Miles se encuentra en una encrucijada.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BODRiZGQyOGEtZWE1OS00MjQ2LWFiNzUtNjgxMDg3MmM0MDNhXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 456288},
#     'contentRating': '7',
#     'genre': 'Animación, Acción, Aventura',
#     'duration': 'PT2H20M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0034583/',
#     'name': 'Casablanca',
#     'description': 'Un cínico expatriado norteamericano, dueño de un café, se debate entre ayudar o no a su antigua amante y a su marido fugitivo a escapar de los nazis en el Marruecos francés.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNTcyN2YzOTAtNDgyNi00YzA2LWIzOTAtNzg0ZjUyNjMzYWIyXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 631551},
#     'contentRating': '16',
#     'genre': 'Drama, Romance, Bélico',
#     'duration': 'PT1H42M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0114814/',
#     'name': 'The Usual Suspects',
#     'alternateName': 'Sospechosos habituales',
#     'description': 'El único superviviente de un terrible tiroteo en un barco relata los eventos que condujeron a esta masacre, empezando con cinco criminales que se encuentran aparentemente al azar en una selección policial de sospechosos habituales.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMDliMWJiOTItOTUzNi00YjdmLTgxYzItZjQyYzU1NmZhZTdiXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1190298},
#     'contentRating': '18',
#     'genre': 'Crimen, Drama, Misterio',
#     'duration': 'PT1H46M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt1675434/',
#     'name': 'Intouchables',
#     'alternateName': 'Intocable',
#     'description': 'Un accidente de parapente deja a un aristócrata cuadripléjico, quien contrata a un joven de un barrio pobre para que sea su cuidador.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BOWFmYzhiODMtZjYzOC00MTgyLWFkN2MtM2VlMDgwMzdkNGNkXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 978939},
#     'contentRating': '7',
#     'genre': 'Comedia, Drama',
#     'duration': 'PT1H52M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0095765/',
#     'name': 'Nuovo Cinema Paradiso',
#     'alternateName': 'Cinema Paradiso',
#     'description': 'Un director de cine recuerda cómo en su infancia se enamoró del cine de su pueblo y entabló una profunda amistad con el proyeccionista.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMTljNzc4YWEtYTZlMS00ODMyLWIwMTAtNWQxY2VkMDEwYTk5XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 301457},
#     'contentRating': 'A',
#     'genre': 'Drama, Romance',
#     'duration': 'PT2H54M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0078748/',
#     'name': 'Alien',
#     'alternateName': 'Alien, el octavo pasajero',
#     'description': 'La tripulación de una nave espacial comercial se encuentra con una forma de vida mortal tras investigar una transmisión desconocida.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BN2NhMDk2MmEtZDQzOC00MmY5LThhYzAtMDdjZGFjOGZjMjdjXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1016568},
#     'contentRating': '16',
#     'genre': 'Terror, Ciencia ficción',
#     'duration': 'PT1H57M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0027977/',
#     'name': 'Modern Times',
#     'alternateName': 'Tiempos modernos',
#     'description': 'Una hombre y una joven sin hogar se enfrentan a la vida moderna en las calles de la sociedad industrial.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjZmMjA4OGQtNjFmZi00ODE1LTkzM2QtYzg4OTM4ZDk2YzNkXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 273141},
#     'contentRating': '16',
#     'genre': 'Comedia, Drama, Romance',
#     'duration': 'PT1H27M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0047396/',
#     'name': 'Rear Window',
#     'alternateName': 'La ventana indiscreta',
#     'description': 'Un fotógrafo en silla de ruedas espía a sus vecinos desde la ventana de su apartamento en Greenwich Village, y se convence de que uno de ellos ha cometido un asesinato, a pesar del escepticismo de su novia, modelo de moda.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjFlZmQwNjUtYTJlOC00MjBiLWE2YTQtMDk1ZGM3YWJmZThmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 546421},
#     'contentRating': '16',
#     'genre': 'Drama, Misterio, Suspense',
#     'duration': 'PT1H52M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0064116/',
#     'name': 'C&apos;era una volta il West',
#     'alternateName': 'Hasta que llegó su hora',
#     'description': 'Un misterioso extraño con una armónica se alía con un famoso forajido para proteger a una bella viuda de un despiadado asesino que trabaja para el ferrocarril.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjEzNjg1NzEwMV5BMl5BanBnXkFtZTgwMTE4OTU0MTE@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 368409},
#     'contentRating': '18',
#     'genre': 'Drama, Del oeste',
#     'duration': 'PT2H46M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt1853728/',
#     'name': 'Django Unchained',
#     'alternateName': 'Django desencadenado',
#     'description': 'Con la ayuda de un cazarrecompensas alemán, un esclavo liberado se propone rescatar a su esposa de un brutal propietario de una plantación en Misisipi.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMTg5NzI5ODU0MV5BMl5BanBnXkFtZTcwNDcyNDY2Nw@@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 1792724},
#     'contentRating': '16',
#     'genre': 'Del oeste',
#     'duration': 'PT2H45M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0021749/',
#     'name': 'City Lights',
#     'alternateName': 'Luces de la ciudad',
#     'description': 'Con la ayuda de un hombre adinerado, borracho e imprevisible, un ingenuo vagabundo que se ha enamorado de una florista ciega intenta conseguir dinero para poder proporcionarle ayuda médica.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNzIwNTQ2MDUxN15BMl5BanBnXkFtZTgwNjU2MjcyMjE@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 207103},
#     'contentRating': 'A',
#     'genre': 'Comedia, Drama, Romance',
#     'duration': 'PT1H27M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0078788/',
#     'name': 'Apocalypse Now',
#     'description': 'Un oficial del ejército estadounidense que sirve en Vietnam recibe el encargo de asesinar a un coronel renegado de las fuerzas especiales que se ve a sí mismo como un dios.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNzI4NDNlNjItMzM1Ni00YTA0LThjZTAtOTdhMGYxYmU0NmZkXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.4,
#      'ratingCount': 742513},
#     'contentRating': '16',
#     'genre': 'Drama, Misterio, Bélico',
#     'duration': 'PT2H27M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt15239678/',
#     'name': 'Dune: Part Two',
#     'alternateName': 'Dune: Parte dos',
#     'description': 'El duque Paul Atreides se une a los Fremen y comienza su entrenamiento para convertirse en Muad&apos;Dib, mientras trata de evitar el terrible futuro que ha previsto: una guerra santa en su nombre, esparciéndose por todo el universo co...',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNzBiMTQ0YjMtZDRhMC00ZDU4LTk3MDMtNWQxOGMwMjQzYjc4XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.5,
#      'ratingCount': 631890},
#     'contentRating': '12',
#     'genre': 'Acción, Aventura, Drama',
#     'duration': 'PT2H46M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0910970/',
#     'name': 'WALL·E',
#     'description': 'En un futuro lejano, un pequeño robot recolector de residuos se embarca inadvertidamente en un viaje espacial que decidirá en última instancia el destino de la humanidad.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjExMTg5OTU0NF5BMl5BanBnXkFtZTcwMjMxMzMzMw@@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.4,
#      'ratingCount': 1261700},
#     'contentRating': 'A',
#     'genre': 'Animación, Aventura, Familiar',
#     'duration': 'PT1H38M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0209144/',
#     'name': 'Memento',
#     'description': 'Un hombre con pérdida de memoria a corto plazo intenta encontrar al asesino de su esposa.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYmQ3MjliNjAtNWFiZS00YWI1LTlmZTktMzBiNDE1NjRhZjU0XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.4,
#      'ratingCount': 1379517},
#     'contentRating': '13',
#     'genre': 'Misterio, Suspense',
#     'duration': 'PT1H53M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0082971/',
#     'name': 'Raiders of the Lost Ark',
#     'alternateName': 'En busca del arca perdida',
#     'description': 'En 1936, el arqueólogo y aventurero Indiana Jones es contratado por el Gobierno de Estados Unidos para encontrar el Arca de la Alianza, antes de que los nazis de Adolf Hitler puedan obtener sus impresionantes poderes.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjhkNDBiMTMtYzNlOS00OTU2LWE3ZGMtZWVmMThkZThjZjMzXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.4,
#      'ratingCount': 1074748},
#     'contentRating': 'A',
#     'genre': 'Acción, Aventura',
#     'duration': 'PT1H55M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0405094/',
#     'name': 'Das Leben der Anderen',
#     'alternateName': 'La vida de los otros',
#     'description': 'En el este de Berlín en 1984 un agente de la policía secreta vigilando a un escritor y su amante se encuentra cada vez más absorto en sus vidas.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BN2Q5M2JhZGItNTg2OC00NjQ1LTllMmYtNWUzODNhMmU3YjcxXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.4,
#      'ratingCount': 427952},
#     'contentRating': '7',
#     'genre': 'Drama, Misterio, Suspense',
#     'duration': 'PT2H17M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt4154756/',
#     'name': 'Avengers: Infinity War',
#     'alternateName': 'Vengadores: Infinity War',
#     'description': 'Los Vengadores y sus aliados estarán dispuestos a sacrificarlo todo para derrotar al poderoso Thanos antes de que su devastación y ruina ponga fin al universo.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BOGVkODYxMDEtODczZC00MjRiLTg3ZWYtZjgzN2QyMDBjZTUzXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.4,
#      'ratingCount': 1288752},
#     'contentRating': '12',
#     'genre': 'Acción, Aventura, Ciencia ficción',
#     'duration': 'PT2H29M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0043014/',
#     'name': 'Sunset Boulevard',
#     'alternateName': 'El crepúsculo de los dioses',
#     'description': 'Un guionista es contratado para reescribir el guion de una estrella de cine mudo en decadencia y acaba desarrollando una peligrosa relación.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZjNmY2FhZDUtNzMxMS00ZDFiLTlhMzEtNTBmZjUwMTIxMzQxXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.4,
#      'ratingCount': 248989},
#     'contentRating': 'Apta para mayores',
#     'genre': 'Drama, Cine negro',
#     'duration': 'PT1H50M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt4633694/',
#     'name': 'Spider-Man: Into the Spider-Verse',
#     'alternateName': 'Spider-Man: Un nuevo universo',
#     'description': 'El adolescente Miles Morales se convierte en el Spider-Man de su universo, y debe unirse a cinco individuos con poderes arácnidos de otras dimensiones para detener una amenaza para todas las realidades.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjMwNDkxMTgzOF5BMl5BanBnXkFtZTgwNTkwNTQ3NjM@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.4,
#      'ratingCount': 731649},
#     'contentRating': '7',
#     'genre': 'Animación, Acción, Aventura',
#     'duration': 'PT1H57M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0051201/',
#     'name': 'Witness for the Prosecution',
#     'alternateName': 'Testigo de cargo',
#     'description': 'Un veterano abogado británico debe defender a su cliente en un juicio por asesinato en el que surge una sorpresa tras otra.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMzEyYzNjOTktMzI5YS00MzQ4LThlOWYtZmQ4OGI0ZDk3YmVmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.4,
#      'ratingCount': 150042},
#     'contentRating': 'A',
#     'genre': 'Crimen, Drama, Misterio',
#     'duration': 'PT1H56M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0050825/',
#     'name': 'Paths of Glory',
#     'alternateName': 'Senderos de gloria',
# ...
#     'name': 'The Exorcist',
#     'alternateName': 'El exorcista',
#     'description': 'Una adolescente es poseída por una entidad malévola y su madre obtiene la ayuda de dos curas para que la liberen.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZjg3YjE4ZjAtYTdmYS00ZTBkLWE1ZjgtNzAzODUwNzRiYjlmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 478092},
#     'contentRating': '18',
#     'genre': 'Terror',
#     'duration': 'PT2H2M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0059742/',
#     'name': 'The Sound of Music',
#     'alternateName': 'Sonrisas y lágrimas',
#     'description': 'Una joven novicia es enviada por su convento en la Austria de los años 30 para convertirse en institutriz de los siete hijos de un oficial de marina viudo.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMTM2Y2QzNzUtODI5Zi00NmEzLWEyOWUtMDhhOGU4NGFkOTYyXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 276678},
#     'contentRating': 'A',
#     'genre': 'Biografía, Drama, Familiar',
#     'duration': 'PT2H52M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0019254/',
#     'name': 'La passion de Jeanne d&apos;Arc',
#     'alternateName': 'La pasión de Juana de Arco',
#     'description': 'En 1431, Juana de Arco es juzgada por herejía. Los juristas eclesiásticos intentan obligar a Juana a retractarse de sus santas visiones.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYWMwMzEyYWQtYTlmNi00MTg0LTliYjUtZTFhMTMxOGEyNjNlXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 65089},
#     'contentRating': '13',
#     'genre': 'Biografía, Drama, Historia',
#     'duration': 'PT1H50M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0032138/',
#     'name': 'The Wizard of Oz',
#     'alternateName': 'El mago de Oz',
#     'description': 'La joven Dorothy y su perro son arrastrados por un tornado desde Kansas a la mágica tierra de Oz, y se embarcan en una búsqueda con tres nuevos amigos para ver al mago, que puede devolverla a su hogar y cumplir los deseos de los d...',
#     'image': 'https://m.media-amazon.com/images/M/MV5BN2Y2ZjUzMDMtZDBkNS00OGE3LTk1NTEtZmRmODJlNzIxNDhiXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 450866},
#     'contentRating': '16',
#     'genre': 'Aventura, Familiar, Fantasía',
#     'duration': 'PT1H42M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0317705/',
#     'name': 'The Incredibles',
#     'alternateName': 'Los Increíbles',
#     'description': 'Mientras intenta llevar una tranquila vida suburbana, una familia de superhéroes encubiertos se ve obligada a entrar en acción para salvar el mundo.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNGNhMDYxNjktZjM1OS00MjI4LTgxYTAtZjIzODQ4NDVjYzU4XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8,
#      'ratingCount': 855908},
#     'contentRating': 'A',
#     'genre': 'Animación, Acción, Aventura',
#     'duration': 'PT1H55M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt1028532/',
#     'name': 'Hachi: A Dog&apos;s Tale',
#     'alternateName': 'Siempre a tu lado (Hachiko)',
#     'description': 'Un profesor universitario crea un vínculo con un perro abandonado al que acoge.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYjkxMjdlNjItZGEzMy00ZDAwLTg3MGEtZWYzYjAyZTdkYjAyXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 328611},
#     'contentRating': 'A',
#     'genre': 'Biografía, Drama, Familiar',
#     'duration': 'PT1H33M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt1979320/',
#     'name': 'Rush',
#     'description': 'La despiadada rivalidad de los años setenta en la Fórmula Uno entre James Hunt y Niki Lauda.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZTQ5NTIyNTEtMDlkNy00MTdmLWJlODktZjQ0NTU4ZjcyMDA3XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 534957},
#     'contentRating': '12',
#     'genre': 'Biografía, Drama, Deporte',
#     'duration': 'PT2H3M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0092005/',
#     'name': 'Stand by Me',
#     'alternateName': 'Cuenta conmigo',
#     'description': 'Tras la muerte de un amigo, un escritor recuerda un viaje de juventud para encontrar el cuerpo de un chico desaparecido.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjc4OTViZGEtNmIwYi00ZGM0LTliNTAtMTliNDhjMGE3NTE2XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 464753},
#     'contentRating': 'A',
#     'genre': 'Aventura, Comedia, Drama',
#     'duration': 'PT1H29M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0476735/',
#     'name': 'Babam ve Oglum',
#     'alternateName': 'Mi padre y mi hijo',
#     'description': 'La familia de un periodista de izquierda queda destrozada tras el golpe militar de Turquía en 1980.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZDE3MTBkNmQtNGFjMC00YTcwLWExY2ItN2MyMGZkNWJlMmFmXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.2,
#      'ratingCount': 97457},
#     'contentRating': 'Not Rated',
#     'genre': 'Drama, Familiar',
#     'duration': 'PT1H52M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0074958/',
#     'name': 'Network',
#     'alternateName': 'Network, un mundo implacable',
#     'description': 'Una cadena de televisión explota cínicamente los desvaríos y las revelaciones de un antiguo ¿miembro? sobre los medios de comunicación para su propio beneficio.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BZjI4ZjU5NDktZTU5YS00ZmQxLWI5YWYtMTJhY2ViMTcwMmJkXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 179349},
#     'contentRating': '18',
#     'genre': 'Drama',
#     'duration': 'PT2H1M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0129167/',
#     'name': 'The Iron Giant',
#     'alternateName': 'El gigante de hierro',
#     'description': 'Un joven se hace amigo de un robot gigante del espacio exterior, que un paranoico agente del Gobierno quiere destruir.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYzVmNmZmM2EtMWJiZi00ZmFiLTljMjEtYjk3OWYyZWZhNmI0XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 245008},
#     'contentRating': 'A',
#     'genre': 'Animación, Acción, Aventura',
#     'duration': 'PT1H26M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt4016934/',
#     'name': 'Ah-ga-ssi',
#     'alternateName': 'La doncella',
#     'description': 'Una mujer es contratada como criada de una heredera japonesa, pero está involucrada en un complot secreto para estafarla.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNTE4MTFkMWYtZDE4ZC00NDg2LTg5MzYtMTU2ZWExMGIyMWQ5XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 188523},
#     'contentRating': '16',
#     'genre': 'Drama, Romance, Suspense',
#     'duration': 'PT2H25M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt5323662/',
#     'name': 'Koe no katachi',
#     'alternateName': 'A Silent Voice',
#     'description': 'Un joven es condenado al ostracismo por sus compañeros de clase tras intimidar a una chica sorda hasta el punto de hacerla cambiar de escuela. Años más tarde, emprende el camino hacia la redención.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BNTY4ZWIxNTctYmFlOC00YjI5LThjN2ItZDllMzIxYjQ3Y2ViXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 120962},
#     'contentRating': '16',
#     'genre': 'Animación, Drama',
#     'duration': 'PT2H10M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0035446/',
#     'name': 'To Be or Not to Be',
#     'alternateName': 'Ser o no ser',
#     'description': 'Durante la ocupación nazi de Polonia, un grupo de actores se ve envuelto en las actividades de un soldado polaco que intenta encontrar a un espía alemán.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjM0ZGQ0YTYtOTc4Ny00ZDc2LWE2NTUtMTJiYmVlZWIxOTY3XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 47092},
#     'contentRating': '14',
#     'genre': 'Comedia, Romance, Bélico',
#     'duration': 'PT1H39M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0058946/',
#     'name': 'La battaglia di Algeri',
#     'alternateName': 'La batalla de Argel',
#     'description': 'En la década de los 50, el miedo y la violencia aumentan a medida que la gente de Algiers lucha por la independencia del gobierno francés.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYTEyYWEzZmMtYTMyNi00NDI0LWIzZTAtOTE1NDIzOTQxNjJiXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 71135},
#     'contentRating': '18',
#     'genre': 'Drama, Bélico',
#     'duration': 'PT2H1M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0032551/',
#     'name': 'The Grapes of Wrath',
#     'alternateName': 'Las uvas de la ira',
#     'description': 'Una familia pobre del Medio Oeste se ve obligada a abandonar sus tierras. Viajan a California, sufriendo las desgracias de los sin techo en la Gran Depresión.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjc4N2RjNWYtYTA2YS00NzA3LWJhNmEtNTJmYmY4ZmJlMzQ1XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 104877},
#     'contentRating': 'A',
#     'genre': 'Drama',
#     'duration': 'PT2H9M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0758758/',
#     'name': 'Into the Wild',
#     'alternateName': 'Hacia rutas salvajes',
#     'description': 'Tras graduarse en la Universidad de Emory, el estudiante y atleta de élite Christopher McCandless abandona sus posesiones, dona a la caridad la totalidad de sus ahorros y viaja en autostop a Alaska para vivir en la naturaleza.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYmVmYmVmNzMtZTk3YS00ZjRlLTk0ZmItNGNlMjZkZWUxN2QxXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8,
#      'ratingCount': 679580},
#     'contentRating': '7',
#     'genre': 'Aventura, Biografía, Drama',
#     'duration': 'PT2H28M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0107048/',
#     'name': 'Groundhog Day',
#     'alternateName': 'Atrapado en el tiempo',
#     'description': 'Un hombre del tiempo revive inexplicablemente el mismo día una y otra vez.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjJiY2NhMTAtNDcyMS00NjU1LWE1ODAtYzc5MTE3MTE5ZTFkXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8,
#      'ratingCount': 716816},
#     'contentRating': 'T',
#     'genre': 'Comedia, Drama, Fantasía',
#     'duration': 'PT1H41M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt1454029/',
#     'name': 'The Help',
#     'alternateName': 'Criadas y señoras (The Help)',
#     'description': 'Un aspirante a autor durante el movimiento por los derechos civiles en los 60 decide escribir un libro des de la perspectiva de las asistentas domésticas afro-americanas sobre las familias blancas para las que trabajan.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BYjQ0ZDQyNTItNDZmZS00ZmVlLTk4NzktOGM2NGQ1NzM4MjVkXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 513213},
#     'contentRating': 'A',
#     'genre': 'Drama',
#     'duration': 'PT2H26M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0245712/',
#     'name': 'Amores perros',
#     'description': 'Un horrible accidente automovilístico conecta tres historias, cada una de ellas con personajes que se enfrentan a la pérdida, el arrepentimiento y las duras realidades de la vida, todo ello en nombre del amor.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMmUzNDI1MDYtNmIxNC00NjczLTk0ZDEtYWFkZDcxMWVhYTEwXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8,
#      'ratingCount': 267914},
#     'contentRating': '18',
#     'genre': 'Drama, Suspense',
#     'duration': 'PT2H34M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt4430212/',
#     'name': 'Drishyam',
#     'description': 'Un hombre toma medidas desesperadas que intentan salvar a su familia del lado oscuro de la ley, luego de que cometen un crimen inesperado.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BM2NmMGFjYTYtNWEwNS00MTM4LWE2ZTktNzZjMTE0OTQyNjFiXkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.2,
#      'ratingCount': 101275},
#     'contentRating': 'Not Rated',
#     'genre': 'Crimen, Drama, Misterio',
#     'duration': 'PT2H43M'}},
#   {'@type': 'ListItem',
#    'item': {'@type': 'Movie',
#     'url': 'https://www.imdb.com/es-es/title/tt0032976/',
#     'name': 'Rebecca',
#     'alternateName': 'Rebeca',
#     'description': 'Una mujer acomplejada hace esfuerzos para adaptarse a su nuevo papel como esposa de un aristócrata y evitar ser intimidada por la presencia fantasmal de su primera esposa.',
#     'image': 'https://m.media-amazon.com/images/M/MV5BMjdlM2Y0ZDQtZmIzMi00NDVhLTk2M2ItMTRiZTRkOGIwNjA2XkEyXkFqcGc@._V1_.jpg',
#     'aggregateRating': {'@type': 'AggregateRating',
#      'bestRating': 10,
#      'worstRating': 1,
#      'ratingValue': 8.1,
#      'ratingCount': 159247},
#     'contentRating': '14',
#     'genre': 'Drama, Misterio, Romance',
#     'duration': 'PT2H10M'}}],
#  '@context': 'https://schema.org',
#  'name': 'Las 250 mejores películas de IMDb',
#  'description': 'Según la calificación de los votantes habituales de IMDb.',
#  'url': 'https://www.imdb.com/es-es/chart/top/'}

# %%
data['itemListElement'][0]['item']['alternateName']
# Out:
# 'Cadena perpetua'

# %%
# en vez de enumerate no complicarse mejor un i = 1, i += 1
